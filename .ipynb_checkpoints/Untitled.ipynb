# %%
from vegasflow import vegas_wrapper
import tensorflow as tf
import numpy as np

def integrand(x, y):
    return np.exp(-(x**2+y**2))

dimensions = 2
iterations = 5
events_per_iteration = int(1e5)
vegas_wrapper(integrand, dimensions, iterations, events_per_iteration, compilable=True)
# Out:
# [WARNING] (vegasflow.monte_carlo) The signature could not be autodiscovered due to argument y
# [WARNING] (vegasflow.monte_carlo) Provide a signature argument to compile with a non-std signature
# Events sent to the computing device: 100.0 %
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/w9/rpt2vk6943b30y910f1djt500000gq/T/ipykernel_62586/3394945908.py in <module>
#       9 iterations = 5
#      10 events_per_iteration = int(1e5)
# ---> 11 vegas_wrapper(integrand, dimensions, iterations, events_per_iteration, compilable=True)
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/vegasflow/vflow.py in vegas_wrapper(integrand, n_dim, n_iter, total_n_events, **kwargs)
#     372         `sigma`: monte carlo error
#     373     """
# --> 374     return wrapper(VegasFlow, integrand, n_dim, n_iter, total_n_events, **kwargs)
#     375
#     376
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/vegasflow/monte_carlo.py in wrapper(integrator_class, integrand, n_dim, n_iter, total_n_events, compilable)
#     625     mc_instance = integrator_class(n_dim, total_n_events)
#     626     mc_instance.compile(integrand, compilable=compilable)
# --> 627     return mc_instance.run_integration(n_iter)
#     628
#     629
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/vegasflow/monte_carlo.py in run_integration(self, n_iter, log_time, histograms)
#     561
#     562             # Run one single iteration and append results
# --> 563             res, error = self._run_iteration()
#     564             all_results.append((res, error))
#     565
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/vegasflow/vflow.py in _run_iteration(self)
#     354     def _run_iteration(self):
#     355         """Runs one iteration of the Vegas integrator"""
# --> 356         return self._iteration_content()
#     357
#     358
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/vegasflow/vflow.py in _iteration_content(self)
#     343     def _iteration_content(self):
#     344         # Compute the result
# --> 345         res, res2, arr_res2 = self.run_event()
#     346         # Compute the error
#     347         err_tmp2 = (self.n_events * res2 - tf.square(res)) / (self.n_events - fone)
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/vegasflow/monte_carlo.py in run_event(self, **kwargs)
#     385             accumulators = []
#     386             for ncalls, pc in zip(events_to_do, percentages):
# --> 387                 res = self.device_run(ncalls, sent_pc=pc, **kwargs)
#     388                 accumulators.append(res)
#     389         return _accumulate(accumulators)
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/vegasflow/monte_carlo.py in device_run(self, ncalls, sent_pc, **kwargs)
#     307             self.release_device(device)
#     308         else:
# --> 309             result = self.event(ncalls=ncalls, **kwargs)
#     310         return result
#     311
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     723     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     724     self._concrete_stateful_fn = (
# --> 725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     726             *args, **kwds))
#     727
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3194     arg_names = base_arg_names + missing_arg_names
#    3195     graph_function = ConcreteFunction(
# -> 3196         func_graph_module.func_graph_from_py_func(
#    3197             self._name,
#    3198             self._python_function,
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# ~/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# TypeError: in user code:
#
#     /Users/Jessica/opt/miniconda3/envs/csc294/lib/python3.9/site-packages/vegasflow/monte_carlo.py:506 run_event  *
#         return self._run_event(new_integrand, **kwargs)
#
#     TypeError: tf__integrand() missing 1 required positional argument: 'y'
