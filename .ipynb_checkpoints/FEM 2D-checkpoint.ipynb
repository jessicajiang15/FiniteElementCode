# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import scipy
import scipy.integrate as integrate
import numpy.linalg as linalg
from multipledispatch import dispatch
import time

import cProfile
from matplotlib.colors import LightSource
import timeit

#scipy sims

# %%
class Point:
    def __init__(self, x, y):
        self.x=x
        self.y=y
        
class Triangle:
    #p_3 is the "tip" i.e. point in the middle of element, p_1 and p_2 are the other two verticies. doesnt matter which order
    def __init__(self, p_1, p_2, p_3):
        self.p1=p_1
        self.p2=p_2
        self.p3=p_3
        
    '''area of this triangle'''
    def area(self):
        p1x, p1y, p2x, p2y, p3x, p3y=self.p1.x, self.p1.y,self.p2.x,self.p2.y,self.p3.x,self.p3.y
        return 0.5*np.abs((p1x*p2y+p3x*p1y+p2x*p3y-p1y*p2x-p2y*p3x-p3y*p1x))
    
    '''finds the area given the point p3 as the new vertex'''
    def area_pt(self,p3):
        return 0.5*np.abs((self.p1.x*self.p2.y+p3.x*self.p1.y+self.p2.x*p3.y-self.p1.y*self.p2.x-self.p2.y*p3.x-p3.y*self.p1.x))
    
    def area_pt_signed(self, p3):
        return 0.5*((self.p1.x*self.p2.y+p3.x*self.p1.y+self.p2.x*p3.y-self.p1.y*self.p2.x-self.p2.y*p3.x-p3.y*self.p1.x))
    
    '''defines if the point x y is in the triangle. if not then returns false otherwise true'''
    '''source: https://stackoverflow.com/questions/2049582/how-to-determine-if-a-point-is-in-a-2d-triangle'''
    def is_in(self,x, y):
        p1x, p1y, p2x, p2y, p3x, p3y=self.p1.x, self.p1.y,self.p2.x,self.p2.y,self.p3.x,self.p3.y
        Area= 0.5 *(-p2y*p3x + p1y*(-p2x + p3x) + p1x*(p2y - p3y) + p2x*p3y)
        s = 1/(2*Area)*(p1y*p3x - p1x*p3y + (p3y - p1y)*x + (p1x - p3x)*y);
        t = 1/(2*Area)*(p1x*p2y - p1y*p2x + (p1y - p2y)*x + (p2x - p1x)*y);
        return 0<=s and t>=0 and 1-s-t>=0
    
    def evaluate(self,x,y):
        return self.area_pt(Point(x, y))/self.area() if self.is_in(x,y) else 0
    
class FiniteElement:
    #top left corner
    def __init__(self, x, y, deltaX, deltaY, config):
        self.deltaX=deltaX
        self.deltaY=deltaY
        
        p1=Point(x, y)
        p2=Point(x+deltaX, y)
        p3=Point(x+2*deltaX, y)
        
        p4=Point(x, y-deltaY)
        center=Point(x+deltaX, y-deltaY)
        p5=Point(x+2*deltaX, y-deltaY)
        
        p6=Point(x, y-2*deltaY)
        p7=Point(x+deltaX, y-2*deltaY)
        p8=Point(x+2*deltaX, y-2*deltaY)
        
        self.triangles=[];
        self.center=center
        
        if(config==0):
        
            #top left
            self.tri_tl=Triangle(p2,p4,center)

            #top right
            self.tri_tr=Triangle(p2,p5,center)

            #bottom left
            self.tri_bl=Triangle(p4, p7, center)

            #bottom right
            self.tri_br=Triangle(p5,p7,center)
            self.triangles.append(self.tri_tl)
            self.triangles.append(self.tri_tr)
            self.triangles.append(self.tri_bl)
            self.triangles.append(self.tri_br)

        else:
            self.tri_tl=Triangle(p1,p2,center)

            self.tri_ul=Triangle(p1, p4, center)

            self.tri_ll=Triangle(p4, p6, center)

            #top right
            self.tri_tr=Triangle(p2,p3,center)

            self.tri_ur=Triangle(p3, p5, center)

            self.tri_lr=Triangle(p5, p8, center)


            #bottom left
            self.tri_bl=Triangle(p6, p7, center)

            #bottom right
            self.tri_br=Triangle(p7,p8,center)
            self.triangles.append(self.tri_tl)
            self.triangles.append(self.tri_tr)
            self.triangles.append(self.tri_bl)
            self.triangles.append(self.tri_br)
            self.triangles.append(self.tri_ll)
            self.triangles.append(self.tri_lr)
            self.triangles.append(self.tri_ul)
            self.triangles.append(self.tri_ur)
            
        self.top_left_x=x
        self.top_left_y=y
        
    def in_region_1(self, x, y):
        return x<self.top_left_x+self.deltaX and y>=self.top_left_y-self.deltaY
    
    def in_region_2(self,x, y):
        return x>=self.top_left_x+self.deltaX and y>=self.top_left_y-self.deltaY
    
    def in_region_3(self,x, y):
        return x<self.top_left_x+self.deltaX and y<self.top_left_y-self.deltaY
    
    def in_region_4(self,x, y):
        return x>=self.top_left_x+self.deltaX and y<self.top_left_y-self.deltaY
    
    def evaluate(self, x, y):
        thesum=0
        for tri in self.triangles:
            thesum+=tri.evaluate(x, y)
            if(thesum>0):
                break            
        return thesum
    
class FEM:
    def __init__(self, N, M, minX, maxX, minY, maxY, electronDensity, eps, boundaryCondition):
        self.N=N
        self.M=M
        self.minX=minX
        self.maxX=maxX
        self.minY=minY
        self.maxY=maxY
        self.deltaX=(maxX-minX)/N
        self.deltaY=(maxY-minY)/M
        #function
        self.electronDensity=electronDensity
        self.finiteElements=self.generateFiniteElements();
        self.eps=eps
        self.boundaryCondition=boundaryCondition
        
        #does not generate the boundary finite elements!
    def generateFiniteElements(self):
        finiteElements=np.ndarray(shape=(self.M-1,self.N-1), dtype=FiniteElement)
        for m in range(0,self.M-1):
            #ignore the last row
            for n in range(0,self.N-1):
                config=0 if n%2==0 else 1
                finiteElements[m, n]=FiniteElement(self.minX+n*self.deltaX, self.maxY-m*self.deltaY, self.deltaX, self.deltaY, config)
        return finiteElements
    
    #p1 gives the indicies
    def integrand(self,x, y, p1):
        return (1/self.eps)*self.electronDensity(x,y)*self.finiteElements[p1.x, p1.y].evaluate(x, y)

    def getIntegral(self,p1):
        temp=self.finiteElements[p1.x, p1.y]
        minX=temp.top_left_x
        maxX=minX+self.deltaX*2
        maxY=temp.top_left_y
        minY=maxY-2*self.deltaY
        return integrate.dblquad(self.integrand, minY, maxY, lambda x: minX, lambda x: maxX, args=[p1])[0]

    def constructBVector(self):
        temp=np.zeros((self.N-1)*(self.M-1))
        for r in range(self.M-1):
            for c in range(self.N-1):
                temp[c+r*(self.N-1)]=self.getIntegral(Point(r,c))
        return temp;
                
    def area(self):
        return self.deltaX*self.deltaY/2
    
    def generateFlagged(self, cols):
        flaggedIndicies1=np.array([self.get1DIndex(0,x, cols) for x in range(self.N+1)]);
        flaggedIndicies2=np.array([self.get1DIndex(y,0, cols) for y in range(self.M+1)]);
        flaggedIndicies3=np.array([self.get1DIndex(self.M,x, cols) for x in range(self.N+1)])
        flaggedIndicies4=np.array([self.get1DIndex(y,self.N, cols) for y in range(self.M+1)]);
        flagged=np.concatenate((flaggedIndicies1,flaggedIndicies2,flaggedIndicies3,flaggedIndicies4))
        return flagged
    
    def constructMatrix(self):
        temp=np.zeros(((self.N+1)*(self.M+1),(self.N+1)*(self.M+1)));
        flagged=self.generateFlagged(self.N+1)
        for m in range(self.M+1):
            for n in range(self.N+1):
                currRow=m*(self.N+1)+n
                index1=self.get1DIndex(m, n-1, self.N+1);
                index2=self.get1DIndex(m+1,n, self.N+1)
                index3=self.get1DIndex(m,n+1, self.N+1)
                index4=self.get1DIndex(m-1,n, self.N+1)
                index5=self.get1DIndex(m,n, self.N+1)
                #print("row, ", currRow)
                if(index1 in range((self.N+1)*(self.M+1))):
                    temp[currRow,index1]=2*(-1/self.deltaX**2)
                if(index2 in range((self.N+1)*(self.M+1))):
                    temp[currRow,index2]=2*(-1/self.deltaY**2)
                if(index3 in range((self.N+1)*(self.M+1))):
                    temp[currRow,index3]=2*(-1/(self.deltaX)**2)
                if(index4 in range((self.N+1)*(self.M+1))):
                    temp[currRow,index4]=2*(-1/self.deltaY**2)
                if(index5 in range((self.N+1)*(self.M+1))):
                    #print("index, ",(currRow,index5))
                    temp[currRow,index5]=4*(1/(self.deltaX)**2+1/self.deltaY**2)
        temp=np.delete(temp, flagged, axis=1)
        temp=np.delete(temp, flagged, axis=0)
        return temp*self.deltaX*self.deltaY/2

    def solveSystem(self):
        b=self.constructBVector();
        b=self.addBoundaryConditions(b, self.M-1, self.N-1)
        M=self.constructMatrix();
        sols=linalg.solve(M, b);
        return self.extractSols(sols);
    
                
    def getPoint(self,m, n):
        return Point(self.minX+n*self.deltaX, self.maxY-m*self.deltaY)
    
    #from 2d to 1d, assume length is self.N+1
    def get1DIndex(self,m, n, cols):
        return cols*m+n
    
    #in entire matrix
    def get2Dindex(self,i):
        return (i//(self.N+1), i%(self.N+1));
    
    #assumes boundary is removed already
    def getBoundaryIndicies2D(self,arr):
        temp=np.array([]);
        for r in range(np.shape(arr)[0]):
            np.append(temp, (r, 0))
            np.append(temp, (r, np.shape(arr)[0]-1))

        for c in range(1, np.shape(arr)[1]-1):
            np.append(temp, (0, c))
            np.append(temp, (np.shape(arr)[0]-1, c))
        return temp
    
    def getBoundaryIndicies1D(self,arr, rows, cols):
        temp=np.array([]);
        for r in range(rows):
            np.append(temp, r*cols)
            np.append(temp, r*cols+cols-1)

        for c in range(1, cols-1):
            np.append(temp, c)
            np.append(temp, rows*cols+c)
        return temp
    
    #assumes boundary is removed from the index
    def getBoundaryXY(self, arr, rows, cols):
        temp=np.array([])
        for i in range(len(arr)):
            r=arr[i]//cols
            c=arr[i]%cols
            if(r==0):
                np.append(temp, np.array([(c+1)*self.deltaX+self.minX, self.maxY]))
            elif(r==rows-1):
                np.append(temp, np.array([(c+1)*self.deltaX+self.minX, self.minY]))
            elif(c==0):
                np.append(temp, np.array([self.minX, self.maxY-(r+1)*self.deltaY]))
            elif(c==cols-1):
                np.append(temp, np.array([self.maxX, self.maxY-(r+1)*self.deltaY]))
        return temp

    def addBoundaryConditions(self, arr, rows, cols):
        temp=np.zeros(np.shape(arr))
        ind=self.getBoundaryIndicies1D(arr, rows, cols);
        xy=self.getBoundaryXY(arr, rows, cols);
        for i in ind:
            temp[i]+=self.boundaryCondition(xy[0],xy[1])*self.deltaX*self.deltaY*(-1/self.deltaY**2);
        return arr;
                
    def fillBoundary(self,temp):
        print(np.shape(temp))
        for i in range(np.shape(temp)[0]):
            pt=self.getPoint(i,0)
            pt1=self.getPoint(i, np.shape(temp)[1]-1)
            temp[i,0]=self.boundaryCondition(pt.x, pt.y)
            temp[i,np.shape(temp)[1]-1]=self.boundaryCondition(pt1.x, pt1.y)
        for i in range(1, np.shape(temp)[1]-1):
            pt=self.getPoint(0,i)
            pt1=self.getPoint(np.shape(temp)[0]-1, i)
            temp[0,i]=self.boundaryCondition(pt.x, pt.y)
            temp[np.shape(temp)[0]-1, i]=self.boundaryCondition(pt1.x, pt1.y)
        return temp
    
    def turnIntoGraphable(self, sols):
        xy=np.zeros(((self.M+1)*(self.N+1),2));
        for m in range(self.M+1):
            for n in range(self.N+1):
                xy[m*(self.N+1)+n,0]=n*self.deltaX+self.minX
                xy[m*(self.N+1)+n,1]=self.maxY-m*self.deltaY
        return (xy, sols.flatten())
    
    def extractSols(self,sols):
        temp=np.zeros((self.M+1, self.N+1));
        for i in range(len(sols)):
            row=i//(self.N-1)+1
            col=i%(self.N-1)+1
            temp[row, col]=sols[i]
        temp=self.fillBoundary(temp);
        return temp;
    
    def getGraphableArrays(self):
        sols=self.solveSystem()
        return self.turnIntoGraphable(sols)
    
    def graphResults(self):
        sols=self.solveSystem()
        graphData=self.turnIntoGraphable(sols)
        xs = graphData[0][:,0]
        ys = graphData[0][:,1]

        function=graphData[1]

        fig = plt.figure()
        ax = plt.axes(projection='3d')

        function.shape = (self.M+1, self.N+1)

        ls = LightSource(azdeg=0, altdeg=65)
        rgb = ls.shade(function, plt.cm.RdYlBu)

        function.shape=((self.M+1)*(self.N+1),)

        new_img = rgb.transpose((2, 0, 1))
        # Dimensions: [3, m, n]
        new_img = rgb.reshape(rgb.shape[0]*rgb.shape[1], rgb.shape[2])

        # Create the SCATTER() plot 
        ax.scatter(xs,ys,function, facecolors=new_img);
    
class Test:
    def __init__(self):
        pass
    
    @staticmethod
    def plot(startX, endX, startY, endY,num, func):
        xs = np.linspace(startX, endX,num=num,axis=0)
        ys = np.linspace(startY, endY,num=num,axis=0)

        output=np.array([[x, y] for x in xs for y in ys])
        function=np.array([func(p[0], p[1]) for p in output])

        fig = plt.figure()
        ax = plt.axes(projection='3d')

        function.shape = (function.size//len(xs), len(xs))

        ls = LightSource(azdeg=0, altdeg=65)
        rgb = ls.shade(function, plt.cm.RdYlBu)

        function.shape=(len(xs)*len(ys),)

        new_img = rgb.transpose((2, 0, 1))
        # Dimensions: [3, m, n]
        new_img = rgb.reshape(rgb.shape[0]*rgb.shape[1], rgb.shape[2])

        # Create the SCATTER() plot 
        ax.scatter(output[:,0],output[:,1],function, facecolors=new_img);
        
    @staticmethod
    def erf_solution(x, y):
        return 1/(4*np.pi*eps)*(1/(np.sqrt(x**2+y**2)))*scipy.special.erf(np.sqrt(x**2+y**2)/np.sqrt(2*a**2))
    @staticmethod    
    def createArrayOfValues(func, minX, minY, maxX, maxY, deltaX, deltaY):
        cols=int((maxX-minX)//deltaX)
        rows=int((maxY-minY)//deltaY)
        temp=np.zeros((rows, cols))
        for r in range(rows):
            for c in range(cols):
                temp[r, c]=func(minX+deltaX*c, maxY-deltaY*r)
        return temp
    @staticmethod    
    def computeGradientMatrix(func, minX, minY, maxX, maxY, deltaX, deltaY):
        values=Test.createArrayOfValues(func, minX, minY, maxX, maxY, deltaX, deltaY)
        return np.gradient(values, deltaX)

# %%
eps=1

minX=-5
maxX=5
minY=-5
maxY=5

N=10
M=10
sigma=1
a=1

def boundaryCondition(x, y):
    return 0
def boundaryCondition(x, y):
    return 1/(4*np.pi*eps)*1/np.sqrt(x**2+y**2)



def electronDensity(x, y):
    return (1/np.sqrt(2*np.pi*sigma**2))**3*(np.exp((-(x**2+y**2))/(2*sigma**2)))

#self, N, M, minX, maxX, minY, maxY, electronDensity, eps, boundaryCondition
finiteElement=FEM(N, M,minX, maxX, minY, maxY, electronDensity, eps, boundaryCondition)

# %%
finiteElement.graphResults()
Test.plot(minX,maxX,minY,maxY,100,Test.erf_solution)
Test.plot(minX,maxX,minY,maxY,100,electronDensity)
# Out:
# (11, 11)

# %%
fsols=finiteElement.solveSystem()
# Out:
# (11, 11)

# %%
fsols
# Out:
# array([[0.01125395, 0.01242791, 0.01364742, 0.01477717, 0.01560643,
#         0.01591549, 0.01560643, 0.01477717, 0.01364742, 0.01242791,
#         0.01125395],
#        [0.01242791, 0.00429159, 0.00858297, 0.01264731, 0.01583473,
#         0.01695775, 0.01583473, 0.01264731, 0.00858297, 0.00429159,
#         0.01242791],
#        [0.01364742, 0.00858335, 0.01739097, 0.02616737, 0.03368013,
#         0.03613465, 0.03368013, 0.02616737, 0.01739097, 0.00858335,
#         0.01364742],
#        [0.01477717, 0.01265045, 0.02619064, 0.04084877, 0.05550739,
#         0.05957269, 0.05550739, 0.04084877, 0.02619064, 0.01265045,
#         0.01477717],
#        [0.01560643, 0.01582366, 0.0335561 , 0.05452333, 0.07908034,
#         0.08487484, 0.07908034, 0.05452333, 0.0335561 , 0.01582366,
#         0.01560643],
#        [0.01591549, 0.01707125, 0.03661038, 0.06064533, 0.09065482,
#         0.09737386, 0.09065482, 0.06064533, 0.03661038, 0.01707125,
#         0.01591549],
#        [0.01560643, 0.01582408, 0.03355725, 0.05452629, 0.07908466,
#         0.08488571, 0.07908466, 0.05452629, 0.03355725, 0.01582408,
#         0.01560643],
#        [0.01477717, 0.01265096, 0.02619186, 0.04085106, 0.05551087,
#         0.05957782, 0.05551087, 0.04085106, 0.02619186, 0.01265096,
#         0.01477717],
#        [0.01364742, 0.00858376, 0.01739188, 0.0261689 , 0.03368231,
#         0.03613731, 0.03368231, 0.0261689 , 0.01739188, 0.00858376,
#         0.01364742],
#        [0.01242791, 0.00429181, 0.00858345, 0.01264807, 0.01583576,
#         0.01695893, 0.01583576, 0.01264807, 0.00858345, 0.00429181,
#         0.01242791],
#        [0.01125395, 0.01242791, 0.01364742, 0.01477717, 0.01560643,
#         0.01591549, 0.01560643, 0.01477717, 0.01364742, 0.01242791,
#         0.01125395]])

# %%
Test.erf_solution(5,-5)
# Out:
# 0.011253953951946524

# %%
finiteElement.boundaryCondition(-5,5)

# %% [markdown]
# cProfile.run('finiteElement.constructBVector()')

# %%
cProfile.run('finiteElement.graphResults()');
# Out:
# (6, 6)
#          26626071 function calls (26605827 primitive calls) in 31.575 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   2230914    3.004    0.000   20.416    0.000 220248860.py:120(evaluate)
#    943411    1.369    0.000    1.369    0.000 220248860.py:14(area)
#   2230914    2.547    0.000   30.121    0.000 220248860.py:155(integrand)
#        16    0.003    0.000   31.516    1.970 220248860.py:158(getIntegral)
#      4956    0.001    0.000    0.001    0.000 220248860.py:164(<lambda>)
#         1    0.001    0.001   31.516   31.516 220248860.py:166(constructBVector)
#         1    0.000    0.000    0.000    0.000 220248860.py:176(generateFlagged)
#         1    0.000    0.000    0.000    0.000 220248860.py:177(<listcomp>)
#         1    0.000    0.000    0.000    0.000 220248860.py:178(<listcomp>)
#         1    0.000    0.000    0.000    0.000 220248860.py:179(<listcomp>)
#         1    0.000    0.000    0.000    0.000 220248860.py:180(<listcomp>)
#         1    0.000    0.000    0.001    0.001 220248860.py:184(constructMatrix)
#    943411    1.701    0.000    1.701    0.000 220248860.py:19(area_pt)
#    943447    0.254    0.000    0.254    0.000 220248860.py:2(__init__)
#         1    0.001    0.001   31.528   31.528 220248860.py:211(solveSystem)
#        20    0.000    0.000    0.000    0.000 220248860.py:219(getPoint)
#       204    0.000    0.000    0.000    0.000 220248860.py:223(get1DIndex)
#         1    0.000    0.000    0.004    0.004 220248860.py:242(getBoundaryIndicies1D)
#         1    0.000    0.000    0.000    0.000 220248860.py:254(getBoundaryXY)
#         1    0.000    0.000    0.004    0.004 220248860.py:269(addBoundaryConditions)
#   8501674   10.709    0.000   10.709    0.000 220248860.py:27(is_in)
#         1    0.000    0.000    0.004    0.004 220248860.py:277(fillBoundary)
#         1    0.000    0.000    0.000    0.000 220248860.py:291(turnIntoGraphable)
#         1    0.000    0.000    0.004    0.004 220248860.py:299(extractSols)
#         1    0.000    0.000   31.576   31.576 220248860.py:312(graphResults)
#   8501674    3.378    0.000   17.412    0.000 220248860.py:34(evaluate)
#        20    0.000    0.000    0.000    0.000 354506029.py:14(boundaryCondition)
#   2230914    7.159    0.000    7.159    0.000 354506029.py:17(electronDensity)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#        19    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(any)
#        28    0.001    0.000    0.003    0.000 <__array_function__ internals>:2(append)
#        11    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_1d)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(broadcast_arrays)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(clip)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(column_stack)
#        54    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(concatenate)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(cumsum)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(delete)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#        17    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(dot)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(gradient)
#         1    0.000    0.000    0.001    0.001 <__array_function__ internals>:2(inv)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(may_share_memory)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(min_scalar_type)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(norm)
#        34    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(ravel)
#        19    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(reshape)
#        29    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(shape)
#         1    0.000    0.000    0.002    0.002 <__array_function__ internals>:2(solve)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(unravel_index)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(where)
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#        66    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000   31.576   31.576 <string>:1(<module>)
#       347    0.000    0.000    0.000    0.000 __init__.py:101(check_in_list)
#         9    0.000    0.000    0.000    0.000 __init__.py:106(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:109(__call__)
#        18    0.000    0.000    0.000    0.000 __init__.py:115(__hash__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1180(is_interactive)
#        16    0.000    0.000    0.000    0.000 __init__.py:119(_weak_or_strong_ref)
#        22    0.000    0.000    0.000    0.000 __init__.py:1277(is_math_text)
#        29    0.000    0.000    0.000    0.000 __init__.py:1290(_to_unmasked_float_array)
#        17    0.000    0.000    0.000    0.000 __init__.py:132(check_shape)
#       2/1    0.000    0.000    0.003    0.003 __init__.py:1409(inner)
#        51    0.000    0.000    0.000    0.000 __init__.py:152(<genexpr>)
#         6    0.000    0.000    0.000    0.000 __init__.py:1619(<lambda>)
#        21    0.000    0.000    0.000    0.000 __init__.py:1661(safe_first_element)
#         5    0.000    0.000    0.000    0.000 __init__.py:1683(sanitize_sequence)
#       118    0.001    0.000    0.001    0.000 __init__.py:1691(normalize_kwargs)
#        14    0.000    0.000    0.000    0.000 __init__.py:171(check_getitem)
#       118    0.000    0.000    0.000    0.000 __init__.py:1730(<dictcomp>)
#        24    0.000    0.000    0.000    0.000 __init__.py:1799(_str_equal)
#        12    0.000    0.000    0.000    0.000 __init__.py:1810(_str_lower_equal)
#        89    0.000    0.000    0.000    0.000 __init__.py:184(__init__)
#     16/10    0.000    0.000    0.001    0.000 __init__.py:1843(method)
#       238    0.000    0.000    0.000    0.000 __init__.py:2014(_setattr_cm)
#         1    0.000    0.000    0.000    0.000 __init__.py:2059(__init__)
#        16    0.000    0.000    0.000    0.000 __init__.py:214(connect)
#        12    0.000    0.000    0.000    0.000 __init__.py:269(wrapper)
#       331    0.000    0.000    0.000    0.000 __init__.py:276(process)
#         9    0.000    0.000    0.000    0.000 __init__.py:469(is_scalar_or_string)
#        12    0.000    0.000    0.001    0.000 __init__.py:512(_get_data_path)
#         2    0.000    0.000    0.000    0.000 __init__.py:570(__init__)
#         3    0.000    0.000    0.000    0.000 __init__.py:598(push)
#         4    0.000    0.000    0.000    0.000 __init__.py:623(clear)
#         1    0.000    0.000    0.000    0.000 __init__.py:628(bubble)
#        79    0.001    0.000    0.001    0.000 __init__.py:65(check_isinstance)
#      1650    0.001    0.000    0.002    0.000 __init__.py:653(__getitem__)
#         2    0.000    0.000    0.000    0.000 __init__.py:700(safe_masked_invalid)
#         1    0.000    0.000    0.000    0.000 __init__.py:73(get_projection_class)
#        12    0.000    0.000    0.000    0.000 __init__.py:80(<genexpr>)
#         2    0.000    0.000    0.000    0.000 __init__.py:817(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:818(<dictcomp>)
#        25    0.000    0.000    0.000    0.000 __init__.py:823(clean)
#        25    0.000    0.000    0.000    0.000 __init__.py:826(<listcomp>)
#        20    0.000    0.000    0.000    0.000 __init__.py:872(get_siblings)
#        20    0.000    0.000    0.000    0.000 __init__.py:876(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:903(delete_masked_points)
#         1    0.000    0.000    0.000    0.000 __init__.py:98(get_projection_class)
#         1    0.000    0.000    0.000    0.000 __init__.py:980(_combine_masks)
#         1    0.000    0.000    0.000    0.000 _axes.py:4046(_parse_scatter_color_args)
#         1    0.000    0.000    0.002    0.002 _axes.py:4196(scatter)
#         1    0.000    0.000    0.000    0.000 _base.py:1055(_set_position)
#        19    0.000    0.000    0.000    0.000 _base.py:1099(_set_artist_props)
#         1    0.000    0.000    0.000    0.000 _base.py:1109(_gen_axes_patch)
#         1    0.000    0.000    0.001    0.001 _base.py:1126(_gen_axes_spines)
#         5    0.000    0.000    0.001    0.000 _base.py:1141(<genexpr>)
#         1    0.000    0.000    0.012    0.012 _base.py:1182(cla)
#         1    0.000    0.000    0.000    0.000 _base.py:1493(_set_title_offset_trans)
#         1    0.000    0.000    0.000    0.000 _base.py:2158(has_data)
#         1    0.000    0.000    0.000    0.000 _base.py:2166(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _base.py:2170(_deprecate_noninstance)
#         1    0.000    0.000    0.001    0.001 _base.py:2223(add_collection)
#         2    0.000    0.000    0.000    0.000 _base.py:223(__init__)
#         2    0.000    0.000    0.000    0.000 _base.py:236(set_prop_cycle)
#         9    0.000    0.000    0.001    0.000 _base.py:2482(_process_unit_info)
#         9    0.000    0.000    0.000    0.000 _base.py:2539(<listcomp>)
#        11    0.000    0.000    0.000    0.000 _base.py:2939(_get_axis_list)
#        44    0.000    0.000    0.000    0.000 _base.py:2940(<genexpr>)
#        10    0.000    0.000    0.000    0.000 _base.py:2942(_get_axis_map)
#         1    0.000    0.000    0.000    0.000 _base.py:3150(set_axisbelow)
#         2    0.000    0.000    0.001    0.000 _base.py:3349(tick_params)
#         1    0.000    0.000    0.000    0.000 _base.py:3428(set_axis_off)
#         1    0.000    0.000    0.000    0.000 _base.py:3516(get_xbound)
#         1    0.000    0.000    0.000    0.000 _base.py:3532(set_xbound)
#        16    0.000    0.000    0.000    0.000 _base.py:3587(_validate_converted_limits)
#         1    0.000    0.000    0.000    0.000 _base.py:3604(set_xlim)
#         1    0.000    0.000    0.000    0.000 _base.py:3860(get_ybound)
#         1    0.000    0.000    0.000    0.000 _base.py:3876(set_ybound)
#         1    0.000    0.000    0.000    0.000 _base.py:3931(set_ylim)
#         1    0.000    0.000    0.000    0.000 _base.py:4198(set_navigate)
#         1    0.000    0.000    0.000    0.000 _base.py:4214(set_navigate_mode)
#         1    0.000    0.000    0.030    0.030 _base.py:553(__init__)
#         1    0.000    0.000    0.000    0.000 _base.py:611(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 _base.py:74(wrapper)
#         1    0.000    0.000    0.000    0.000 _base.py:751(set_figure)
#         1    0.000    0.000    0.000    0.000 _base.py:765(_unstale_viewLim)
#         1    0.000    0.000    0.000    0.000 _base.py:768(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 _base.py:769(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _base.py:786(_request_autoscale_view)
#         2    0.000    0.000    0.000    0.000 _base.py:788(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 _base.py:803(_set_lim_and_transforms)
#     56/30    0.000    0.000    0.000    0.000 _base.py:839(get_xaxis_transform)
#         6    0.000    0.000    0.000    0.000 _base.py:863(get_xaxis_text1_transform)
#         6    0.000    0.000    0.000    0.000 _base.py:889(get_xaxis_text2_transform)
#         1    0.000    0.000    0.000    0.000 _base.py:991(_update_transScale)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:779(items)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:802(__init__)
#         5    0.000    0.000    0.000    0.000 _collections_abc.py:849(__iter__)
#         4    0.000    0.000    0.000    0.000 _methods.py:101(_clip_dep_is_byte_swapped)
#         2    0.000    0.000    0.000    0.000 _methods.py:106(_clip_dep_invoke_with_casting)
#         2    0.000    0.000    0.000    0.000 _methods.py:125(_clip)
#         4    0.000    0.000    0.000    0.000 _methods.py:38(_amax)
#         4    0.000    0.000    0.000    0.000 _methods.py:42(_amin)
#         7    0.000    0.000    0.000    0.000 _methods.py:54(_any)
#         7    0.000    0.000    0.001    0.000 _methods.py:60(_all)
#         4    0.000    0.000    0.000    0.000 _methods.py:91(_clip_dep_is_scalar_nan)
#         2    0.000    0.000    0.000    0.000 _pylab_helpers.py:105(get_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:110(_set_new_active_manager)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:123(set_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:34(get_fig_manager)
#         1    0.000    0.000    0.033    0.033 _subplots.py:14(__init__)
#         1    0.000    0.000    0.001    0.001 _subplots.py:58(set_subplotspec)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:131(geterr)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__enter__)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:434(__exit__)
#       151    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#        13    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#         3    0.000    0.000    0.000    0.000 art3d.py:293(set_segments)
#         1    0.000    0.000    0.000    0.000 art3d.py:539(set_3d_properties)
#         1    0.000    0.000    0.000    0.000 art3d.py:650(patch_collection_2d_to_3d)
#         1    0.000    0.000    0.000    0.000 art3d.py:894(juggle_axes)
#        69    0.000    0.000    0.000    0.000 artist.py:1001(set_visible)
#         1    0.000    0.000    0.000    0.000 artist.py:1033(set_in_layout)
#       119    0.001    0.000    0.003    0.000 artist.py:1046(update)
#         2    0.000    0.000    0.000    0.000 artist.py:1072(get_label)
#         2    0.000    0.000    0.000    0.000 artist.py:1076(set_label)
#        23    0.000    0.000    0.000    0.000 artist.py:1096(set_zorder)
#        67    0.000    0.000    0.003    0.000 artist.py:1159(set)
#        67    0.000    0.000    0.003    0.000 artist.py:116(<lambda>)
#        19    0.000    0.000    0.000    0.000 artist.py:1298(mouseover)
#        66    0.002    0.000    0.002    0.000 artist.py:149(__init__)
#        48    0.000    0.000    0.000    0.000 artist.py:242(convert_xunits)
#        48    0.000    0.000    0.000    0.000 artist.py:254(convert_yunits)
#       527    0.000    0.000    0.000    0.000 artist.py:266(axes)
#        98    0.000    0.000    0.000    0.000 artist.py:271(axes)
# 1402/1234    0.001    0.000    0.001    0.000 artist.py:290(stale)
#       322    0.000    0.000    0.001    0.000 artist.py:405(pchanged)
#        19    0.000    0.000    0.000    0.000 artist.py:418(is_transform_set)
#        57    0.000    0.000    0.000    0.000 artist.py:426(set_transform)
#        17    0.000    0.000    0.000    0.000 artist.py:439(get_transform)
#        71    0.000    0.000    0.000    0.000 artist.py:723(set_figure)
#         3    0.000    0.000    0.000    0.000 artist.py:747(set_clip_box)
#        16    0.000    0.000    0.004    0.000 artist.py:759(set_clip_path)
#       156    0.000    0.000    0.000    0.000 artist.py:81(_stale_axes_callback)
#         2    0.000    0.000    0.000    0.000 artist.py:828(get_visible)
#      1402    0.000    0.000    0.000    0.000 artist.py:832(get_animated)
#         1    0.000    0.000    0.000    0.000 artist.py:855(get_clip_path)
#        13    0.000    0.000    0.000    0.000 artist.py:960(set_alpha)
#         1    0.000    0.000    0.000    0.000 artist.py:978(_set_alpha_for_array)
#         1    0.000    0.000    0.000    0.000 axes3d.py:1015(set_proj_type)
#         1    0.000    0.000    0.000    0.000 axes3d.py:1086(mouse_init)
#         1    0.000    0.000    0.016    0.016 axes3d.py:1124(cla)
#         3    0.000    0.000    0.000    0.000 axes3d.py:1329(grid)
#         2    0.000    0.000    0.001    0.000 axes3d.py:1369(tick_params)
#         1    0.000    0.000    0.000    0.000 axes3d.py:1410(zaxis_inverted)
#         1    0.000    0.000    0.000    0.000 axes3d.py:1417(get_zbound)
#         1    0.000    0.000    0.000    0.000 axes3d.py:1427(set_zbound)
#         2    0.000    0.000    0.000    0.000 axes3d.py:172(set_axis_on)
#         4    0.000    0.000    0.000    0.000 axes3d.py:176(convert_zunits)
#         1    0.000    0.000    0.000    0.000 axes3d.py:183(set_top_view)
#         1    0.000    0.000    0.010    0.010 axes3d.py:195(_init_axis)
#         1    0.000    0.000    0.003    0.003 axes3d.py:2322(scatter)
#         1    0.000    0.000    0.000    0.000 axes3d.py:2376(<listcomp>)
#         1    0.000    0.000    0.000    0.000 axes3d.py:317(set_box_aspect)
#         3    0.000    0.000    0.000    0.000 axes3d.py:479(_unit_change_handler)
#         1    0.000    0.000    0.000    0.000 axes3d.py:490(update_datalim)
#         1    0.000    0.000    0.000    0.000 axes3d.py:535(set_zmargin)
#         1    0.000    0.000    0.031    0.031 axes3d.py:55(__init__)
#         1    0.000    0.000    0.001    0.001 axes3d.py:644(auto_scale_xyz)
#         1    0.000    0.000    0.000    0.000 axes3d.py:658(autoscale_view)
#         2    0.000    0.000    0.001    0.000 axes3d.py:727(set_xlim3d)
#         2    0.000    0.000    0.000    0.000 axes3d.py:784(set_ylim3d)
#         2    0.000    0.000    0.000    0.000 axes3d.py:842(set_zlim3d)
#         3    0.000    0.000    0.000    0.000 axes3d.py:900(get_xlim3d)
#         3    0.000    0.000    0.000    0.000 axes3d.py:904(get_ylim3d)
#         4    0.000    0.000    0.000    0.000 axes3d.py:908(get_zlim3d)
#         1    0.000    0.000    0.000    0.000 axes3d.py:979(view_init)
#         6    0.000    0.000    0.000    0.000 axis.py:1015(_set_artist_props)
#        11    0.000    0.000    0.000    0.000 axis.py:1352(get_major_locator)
#        10    0.000    0.000    0.000    0.000 axis.py:1437(update_units)
#         6    0.000    0.000    0.000    0.000 axis.py:148(<dictcomp>)
#        10    0.000    0.000    0.000    0.000 axis.py:1492(have_units)
#        18    0.000    0.000    0.000    0.000 axis.py:1495(convert_units)
#         6    0.000    0.000    0.000    0.000 axis.py:1512(set_units)
#        12    0.000    0.000    0.000    0.000 axis.py:1567(set_major_formatter)
#        12    0.000    0.000    0.000    0.000 axis.py:1593(set_minor_formatter)
#        24    0.000    0.000    0.000    0.000 axis.py:1607(_set_formatter)
#        12    0.000    0.000    0.000    0.000 axis.py:1633(set_major_locator)
#        12    0.000    0.000    0.000    0.000 axis.py:1649(set_minor_locator)
#         6    0.000    0.000    0.000    0.000 axis.py:190(_set_labelrotation)
#         8    0.000    0.000    0.000    0.000 axis.py:1985(getter)
#      12/6    0.000    0.000    0.000    0.000 axis.py:1989(setter)
#         3    0.000    0.000    0.005    0.002 axis.py:2013(__init__)
#         6    0.000    0.000    0.000    0.000 axis.py:202(_apply_tickdir)
#         6    0.000    0.000    0.009    0.001 axis.py:2052(_get_tick)
#         6    0.000    0.000    0.000    0.000 axis.py:222(get_tick_padding)
#         8    0.000    0.000    0.000    0.000 axis.py:2239(get_minpos)
#         6    0.000    0.000    0.002    0.000 axis.py:236(set_clip_path)
#        30    0.000    0.000    0.000    0.000 axis.py:340(_set_artist_props)
#         6    0.000    0.000    0.001    0.000 axis.py:349(_apply_params)
#        30    0.000    0.000    0.000    0.000 axis.py:357(<genexpr>)
#         6    0.000    0.000    0.000    0.000 axis.py:374(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 axis.py:387(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 axis.py:392(<dictcomp>)
#         6    0.000    0.000    0.009    0.001 axis.py:414(__init__)
#         6    0.000    0.000    0.000    0.000 axis.py:436(_get_text1_transform)
#         6    0.000    0.000    0.000    0.000 axis.py:439(_get_text2_transform)
#         6    0.000    0.000    0.001    0.000 axis.py:442(_apply_tickdir)
#         6    0.000    0.000    0.000    0.000 axis.py:453(update_position)
#         6    0.000    0.000    0.000    0.000 axis.py:541(__init__)
#        11    0.000    0.000    0.000    0.000 axis.py:547(locator)
#        24    0.000    0.000    0.000    0.000 axis.py:551(locator)
#        45    0.000    0.000    0.000    0.000 axis.py:558(formatter)
#        24    0.000    0.000    0.000    0.000 axis.py:562(formatter)
#         6    0.000    0.000    0.007    0.001 axis.py:57(__init__)
#         6    0.000    0.000    0.009    0.001 axis.py:581(__get__)
#         3    0.000    0.000    0.004    0.001 axis.py:638(__init__)
#        24    0.000    0.000    0.000    0.000 axis.py:687(isDefault_majloc)
#        24    0.000    0.000    0.000    0.000 axis.py:695(isDefault_majfmt)
#        24    0.000    0.000    0.000    0.000 axis.py:703(isDefault_minloc)
#        24    0.000    0.000    0.000    0.000 axis.py:711(isDefault_minfmt)
#         2    0.000    0.000    0.000    0.000 axis.py:752(get_transform)
#         2    0.000    0.000    0.000    0.000 axis.py:755(get_scale)
#        12    0.000    0.000    0.005    0.000 axis.py:759(_set_scale)
#         8    0.000    0.000    0.000    0.000 axis.py:771(limit_range_for_scale)
#         6    0.000    0.000    0.006    0.001 axis.py:790(clear)
#         6    0.000    0.000    0.003    0.001 axis.py:830(reset_ticks)
#         6    0.000    0.000    0.001    0.000 axis.py:850(set_tick_params)
#         6    0.000    0.000    0.000    0.000 axis.py:889(_translate_tick_kw)
#         3    0.000    0.000    0.012    0.004 axis.py:934(set_clip_path)
#         2    0.000    0.000    0.000    0.000 axis.py:977(get_inverted)
#         3    0.000    0.000    0.004    0.001 axis3d.py:113(init3d)
#         3    0.000    0.000    0.000    0.000 axis3d.py:158(set_pane_color)
#         3    0.000    0.000    0.000    0.000 axis3d.py:166(set_rotate_label)
#         3    0.000    0.000    0.000    0.000 axis3d.py:503(d_interval)
#         3    0.000    0.000    0.000    0.000 axis3d.py:511(v_interval)
#         3    0.000    0.000    0.006    0.002 axis3d.py:54(__init__)
#         2    0.001    0.000    0.001    0.000 backend_bases.py:1689(__init__)
#         7    0.000    0.000    0.000    0.000 backend_bases.py:1710(<lambda>)
#         6    0.000    0.000    0.000    0.000 backend_bases.py:2384(mpl_connect)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2771(__init__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2790(notify_axes_change)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2847(set_window_title)
#         1    0.000    0.000    0.009    0.009 backend_bases.py:3467(new_figure_manager)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3476(new_figure_manager_given_figure)
#         1    0.001    0.001    0.001    0.001 backend_inline.py:59(draw_if_interactive)
#         4    0.000    0.000    0.000    0.000 cm.py:259(get_cmap)
#         4    0.000    0.000    0.001    0.000 cm.py:342(__init__)
#         4    0.000    0.000    0.000    0.000 cm.py:537(set_cmap)
#        12    0.000    0.000    0.000    0.000 cm.py:551(norm)
#         4    0.000    0.000    0.001    0.000 cm.py:555(norm)
#         4    0.000    0.000    0.001    0.000 cm.py:575(set_norm)
#         1    0.000    0.000    0.000    0.000 collections.py:1016(set_paths)
#         1    0.000    0.000    0.000    0.000 collections.py:1020(get_paths)
#         3    0.000    0.000    0.002    0.001 collections.py:1390(__init__)
#         3    0.000    0.000    0.000    0.000 collections.py:1446(set_segments)
#         3    0.000    0.000    0.000    0.000 collections.py:1456(<listcomp>)
#         3    0.000    0.000    0.000    0.000 collections.py:1486(_get_default_linewidth)
#         3    0.000    0.000    0.000    0.000 collections.py:1489(_get_default_antialiased)
#         3    0.000    0.000    0.000    0.000 collections.py:1492(_get_default_edgecolor)
#         1    0.000    0.000    0.000    0.000 collections.py:233(get_offset_transform)
#         1    0.000    0.000    0.000    0.000 collections.py:252(get_datalim)
#         4    0.000    0.000    0.000    0.000 collections.py:438(set_pickradius)
#         4    0.000    0.000    0.000    0.000 collections.py:490(set_urls)
#         4    0.000    0.000    0.000    0.000 collections.py:513(set_hatch)
#         1    0.000    0.000    0.000    0.000 collections.py:568(get_offsets)
#         1    0.000    0.000    0.000    0.000 collections.py:572(_get_default_linewidth)
#         4    0.000    0.000    0.000    0.000 collections.py:576(set_linewidth)
#         4    0.000    0.000    0.000    0.000 collections.py:596(set_linestyle)
#         8    0.000    0.000    0.000    0.000 collections.py:671(_bcast_lwls)
#         8    0.000    0.000    0.000    0.000 collections.py:704(<listcomp>)
#         4    0.000    0.000    0.000    0.000 collections.py:709(set_antialiased)
#         1    0.000    0.000    0.000    0.000 collections.py:722(_get_default_antialiased)
#         6    0.000    0.000    0.000    0.000 collections.py:746(_set_facecolor)
#         4    0.000    0.000    0.000    0.000 collections.py:753(set_facecolor)
#         4    0.000    0.000    0.002    0.001 collections.py:77(__init__)
#         6    0.000    0.000    0.000    0.000 collections.py:783(_set_edgecolor)
#         4    0.000    0.000    0.000    0.000 collections.py:802(set_edgecolor)
#         1    0.000    0.000    0.000    0.000 collections.py:820(set_alpha)
#         1    0.000    0.000    0.000    0.000 collections.py:844(_set_mappable_flags)
#         1    0.000    0.000    0.000    0.000 collections.py:878(update_scalarmappable)
#         1    0.000    0.000    0.000    0.000 collections.py:962(set_sizes)
#         1    0.000    0.000    0.000    0.000 collections.py:997(__init__)
#       170    0.000    0.000    0.001    0.000 colors.py:106(_is_nth_color)
#        45    0.000    0.000    0.001    0.000 colors.py:111(is_color_like)
#         5    0.000    0.000    0.000    0.000 colors.py:1113(__init__)
#         2    0.000    0.000    0.000    0.000 colors.py:1141(vmin)
#         2    0.000    0.000    0.000    0.000 colors.py:1152(vmax)
#         1    0.000    0.000    0.000    0.000 colors.py:1163(clip)
#         3    0.000    0.000    0.000    0.000 colors.py:1180(process_value)
#         1    0.000    0.000    0.000    0.000 colors.py:1215(__call__)
#        45    0.000    0.000    0.001    0.000 colors.py:124(_check_color_like)
#         1    0.000    0.000    0.000    0.000 colors.py:1278(autoscale_None)
#       125    0.000    0.000    0.001    0.000 colors.py:152(to_rgba)
#         1    0.000    0.000    0.000    0.000 colors.py:1981(_vector_magnitude)
#         1    0.000    0.000    0.000    0.000 colors.py:2002(__init__)
#         1    0.000    0.000    0.000    0.000 colors.py:2033(direction)
#         1    0.000    0.000    0.000    0.000 colors.py:2046(hillshade)
#         1    0.000    0.000    0.000    0.000 colors.py:2099(shade_normals)
#         1    0.000    0.000    0.001    0.001 colors.py:2145(shade)
#         1    0.000    0.000    0.000    0.000 colors.py:2220(shade_rgb)
#         1    0.000    0.000    0.000    0.000 colors.py:2384(blend_overlay)
#        10    0.000    0.000    0.000    0.000 colors.py:287(to_rgba_array)
#         1    0.000    0.000    0.000    0.000 colors.py:589(__call__)
#        10    0.000    0.000    0.000    0.000 colors.py:96(_sanitize_extrema)
#       119    0.000    0.000    0.001    0.000 contextlib.py:114(__enter__)
#       119    0.000    0.000    0.000    0.000 contextlib.py:123(__exit__)
#       119    0.000    0.000    0.000    0.000 contextlib.py:261(helper)
#       119    0.000    0.000    0.000    0.000 contextlib.py:86(__init__)
#         1    0.000    0.000    0.000    0.000 copy.py:258(_reconstruct)
#         1    0.001    0.001    0.001    0.001 copy.py:66(copy)
#         1    0.000    0.000    0.000    0.000 copyreg.py:94(__newobj__)
#        12    0.000    0.000    0.000    0.000 core.py:1278(_replace_dtype_fields_recursive)
#        12    0.000    0.000    0.000    0.000 core.py:1310(_replace_dtype_fields)
#        12    0.000    0.000    0.000    0.000 core.py:1324(make_mask_descr)
#        42    0.000    0.000    0.000    0.000 core.py:1357(getmask)
#         3    0.000    0.000    0.000    0.000 core.py:1419(getmaskarray)
#         2    0.000    0.000    0.000    0.000 core.py:1540(_shrink_mask)
#         3    0.000    0.000    0.000    0.000 core.py:1639(make_mask_none)
#         1    0.000    0.000    0.000    0.000 core.py:1812(_check_mask_axis)
#         3    0.000    0.000    0.000    0.000 core.py:2334(masked_invalid)
#         1    0.000    0.000    0.000    0.000 core.py:2580(wrapped_method)
#         9    0.000    0.000    0.000    0.000 core.py:2817(__new__)
#        30    0.000    0.000    0.000    0.000 core.py:2948(_update_from)
#        22    0.000    0.000    0.000    0.000 core.py:2974(__array_finalize__)
#         1    0.000    0.000    0.000    0.000 core.py:3067(__array_wrap__)
#         1    0.000    0.000    0.000    0.000 core.py:3085(<listcomp>)
#         3    0.000    0.000    0.000    0.000 core.py:3123(view)
#         7    0.000    0.000    0.000    0.000 core.py:3213(__getitem__)
#         2    0.000    0.000    0.000    0.000 core.py:3227(_is_scalar)
#         2    0.000    0.000    0.000    0.000 core.py:3230(_scalar_heuristic)
#        48    0.000    0.000    0.000    0.000 core.py:3405(dtype)
#        11    0.000    0.000    0.000    0.000 core.py:3421(shape)
#         3    0.000    0.000    0.000    0.000 core.py:3504(mask)
#         2    0.000    0.000    0.000    0.000 core.py:3601(shrink_mask)
#        20    0.000    0.000    0.000    0.000 core.py:3637(_get_data)
#         3    0.000    0.000    0.000    0.000 core.py:3731(filled)
#         3    0.000    0.000    0.000    0.000 core.py:428(_check_fill_value)
#         4    0.000    0.000    0.000    0.000 core.py:4540(ravel)
#         1    0.000    0.000    0.000    0.000 core.py:4857(any)
#         4    0.000    0.000    0.000    0.000 core.py:582(filled)
#         1    0.000    0.000    0.000    0.000 core.py:5994(<lambda>)
#         4    0.000    0.000    0.000    0.000 core.py:6549(array)
#         8    0.000    0.000    0.000    0.000 core.py:6566(is_masked)
#         8    0.000    0.000    0.000    0.000 core.py:666(getdata)
#         4    0.000    0.000    0.000    0.000 core.py:6765(__call__)
#         2    0.000    0.000    0.000    0.000 core.py:7142(reshape)
#         2    0.000    0.000    0.000    0.000 core.py:778(is_string_or_list_of_strings)
#         1    0.000    0.000    0.000    0.000 core.py:7907(asarray)
#         4    0.000    0.000    0.000    0.000 core.py:7956(asanyarray)
#        15    0.000    0.000    0.000    0.000 cycler.py:165(keys)
#       143    0.000    0.000    0.000    0.000 cycler.py:239(__iter__)
#        13    0.000    0.000    0.000    0.000 cycler.py:364(by_key)
#        13    0.000    0.000    0.000    0.000 cycler.py:386(<dictcomp>)
#         1    0.000    0.000    0.001    0.001 decorators.py:41(wrapper)
#        19    0.000    0.000    0.000    0.000 deprecation.py:291(wrapper)
#         1    0.000    0.000    0.001    0.001 deprecation.py:381(wrapper)
#         1    0.000    0.000    0.030    0.030 deprecation.py:445(wrapper)
#       106    0.000    0.000    0.000    0.000 enum.py:358(__call__)
#       106    0.000    0.000    0.000    0.000 enum.py:670(__new__)
#         1    0.000    0.000    0.000    0.000 extras.py:289(__call__)
#         1    0.000    0.000    0.000    0.000 extras.py:291(<listcomp>)
#         1    0.000    0.000    0.000    0.000 extras.py:292(<listcomp>)
#         3    0.000    0.000    0.000    0.000 figure.py:100(__call__)
#         2    0.000    0.000    0.000    0.000 figure.py:112(__contains__)
#         1    0.000    0.000    0.000    0.000 figure.py:121(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:1477(sca)
#         1    0.000    0.000    0.000    0.000 figure.py:1548(_process_projection_requirements)
#         2    0.000    0.000    0.000    0.000 figure.py:155(update)
#         1    0.000    0.000    0.001    0.001 figure.py:186(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:1921(_set_artist_props)
#         1    0.001    0.001    0.009    0.009 figure.py:2147(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:2362(axes)
#         2    0.000    0.000    0.000    0.000 figure.py:2378(_get_dpi)
#         1    0.000    0.000    0.000    0.000 figure.py:2405(set_tight_layout)
#         1    0.000    0.000    0.000    0.000 figure.py:2431(set_constrained_layout)
#         1    0.000    0.000    0.000    0.000 figure.py:2461(set_constrained_layout_pads)
#         2    0.000    0.000    0.000    0.000 figure.py:2526(set_canvas)
#         1    0.000    0.000    0.000    0.000 figure.py:2743(clf)
#         1    0.000    0.000    0.000    0.000 figure.py:2883(add_axobserver)
#         1    0.000    0.000    0.000    0.000 figure.py:2887(<lambda>)
#        12    0.000    0.000    0.000    0.000 figure.py:46(_stale_figure_callback)
#         2    0.000    0.000    0.000    0.000 figure.py:61(__init__)
#         1    0.000    0.000    0.033    0.033 figure.py:646(add_subplot)
#         4    0.000    0.000    0.000    0.000 figure.py:65(as_list)
#         4    0.000    0.000    0.000    0.000 figure.py:69(<listcomp>)
#         1    0.000    0.000    0.000    0.000 figure.py:71(_entry_from_axes)
#         2    0.000    0.000    0.000    0.000 figure.py:72(<genexpr>)
#         1    0.000    0.000    0.000    0.000 figure.py:776(_add_axes_internal)
#         1    0.000    0.000    0.000    0.000 figure.py:78(bubble)
#         2    0.000    0.000    0.000    0.000 figure.py:84(add)
#       108    0.000    0.000    0.000    0.000 font_manager.py:1022(_normalize_font_family)
#        19    0.000    0.000    0.000    0.000 font_manager.py:1109(get_default_size)
#        12    0.000    0.000    0.001    0.000 font_manager.py:1248(findfont)
#        72    0.000    0.000    0.000    0.000 font_manager.py:1304(<genexpr>)
#        54    0.000    0.000    0.002    0.000 font_manager.py:658(__init__)
#        21    0.000    0.000    0.001    0.000 font_manager.py:687(_from_any)
#        36    0.000    0.000    0.000    0.000 font_manager.py:710(__hash__)
#        12    0.000    0.000    0.000    0.000 font_manager.py:721(__eq__)
#        36    0.000    0.000    0.000    0.000 font_manager.py:727(get_family)
#        36    0.000    0.000    0.000    0.000 font_manager.py:739(get_style)
#        36    0.000    0.000    0.000    0.000 font_manager.py:746(get_variant)
#        36    0.000    0.000    0.000    0.000 font_manager.py:752(get_weight)
#        36    0.000    0.000    0.000    0.000 font_manager.py:761(get_stretch)
#        36    0.000    0.000    0.000    0.000 font_manager.py:775(get_size_in_points)
#        36    0.000    0.000    0.000    0.000 font_manager.py:778(get_file)
#        54    0.000    0.000    0.000    0.000 font_manager.py:794(set_family)
#        54    0.000    0.000    0.000    0.000 font_manager.py:807(set_style)
#        54    0.000    0.000    0.000    0.000 font_manager.py:817(set_variant)
#        57    0.000    0.000    0.000    0.000 font_manager.py:826(set_weight)
#        54    0.000    0.000    0.000    0.000 font_manager.py:844(set_stretch)
#        72    0.000    0.000    0.000    0.000 font_manager.py:862(set_size)
#        54    0.000    0.000    0.000    0.000 font_manager.py:887(set_file)
#        36    0.000    0.000    0.000    0.000 font_manager.py:907(get_math_fontfamily)
#        54    0.000    0.000    0.000    0.000 font_manager.py:915(set_math_fontfamily)
#        23    0.000    0.000    0.001    0.000 font_manager.py:943(copy)
#        34    0.000    0.000    0.000    0.000 fromnumeric.py:1714(_ravel_dispatcher)
#        34    0.001    0.000    0.001    0.000 fromnumeric.py:1718(ravel)
#        29    0.000    0.000    0.000    0.000 fromnumeric.py:1924(_shape_dispatcher)
#        29    0.000    0.000    0.000    0.000 fromnumeric.py:1928(shape)
#        19    0.000    0.000    0.000    0.000 fromnumeric.py:193(_reshape_dispatcher)
#        19    0.000    0.000    0.000    0.000 fromnumeric.py:198(reshape)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2042(_clip_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2046(clip)
#        19    0.000    0.000    0.000    0.000 fromnumeric.py:2263(_any_dispatcher)
#        19    0.000    0.000    0.000    0.000 fromnumeric.py:2268(any)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2362(_all_dispatcher)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2367(all)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2454(_cumsum_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2458(cumsum)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:3123(_ndim_dispatcher)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:3127(ndim)
#        21    0.000    0.000    0.000    0.000 fromnumeric.py:38(_wrapit)
#        23    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#        24    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#        24    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#        12    0.000    0.000    0.000    0.000 function_base.py:1160(_diff_dispatcher)
#        12    0.000    0.000    0.000    0.000 function_base.py:1164(diff)
#       111    0.000    0.000    0.000    0.000 function_base.py:244(iterable)
#         2    0.000    0.000    0.000    0.000 function_base.py:4378(_delete_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:4382(delete)
#        28    0.000    0.000    0.000    0.000 function_base.py:4758(_append_dispatcher)
#        28    0.001    0.000    0.002    0.000 function_base.py:4762(append)
#         4    0.000    0.000    0.000    0.000 function_base.py:809(_gradient_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:814(gradient)
#        14    0.000    0.000    0.000    0.000 getlimits.py:382(__new__)
#         1    0.000    0.000    0.000    0.000 gridspec.py:121(set_height_ratios)
#         1    0.000    0.000    0.001    0.001 gridspec.py:143(get_grid_positions)
#         1    0.000    0.000    0.000    0.000 gridspec.py:188(<listcomp>)
#         1    0.000    0.000    0.000    0.000 gridspec.py:196(<listcomp>)
#         1    0.000    0.000    0.000    0.000 gridspec.py:204(_check_gridspec_exists)
#         1    0.000    0.000    0.000    0.000 gridspec.py:225(__getitem__)
#         1    0.000    0.000    0.000    0.000 gridspec.py:229(_normalize)
#         1    0.000    0.000    0.000    0.000 gridspec.py:31(__init__)
#         1    0.000    0.000    0.000    0.000 gridspec.py:333(__init__)
#         1    0.000    0.000    0.001    0.001 gridspec.py:417(get_subplot_params)
#         1    0.000    0.000    0.000    0.000 gridspec.py:433(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 gridspec.py:557(__init__)
#         1    0.000    0.000    0.000    0.000 gridspec.py:567(_from_subplot_args)
#         1    0.000    0.000    0.000    0.000 gridspec.py:614(num2)
#         1    0.000    0.000    0.000    0.000 gridspec.py:618(num2)
#         1    0.000    0.000    0.000    0.000 gridspec.py:625(get_gridspec)
#         1    0.000    0.000    0.001    0.001 gridspec.py:666(get_position)
#         3    0.000    0.000    0.000    0.000 gridspec.py:73(get_geometry)
#         1    0.000    0.000    0.000    0.000 gridspec.py:99(set_width_ratios)
#        13    0.000    0.000    0.000    0.000 hatch.py:182(_validate_hatch_pattern)
#         3    0.000    0.000    0.001    0.000 iostream.py:206(schedule)
#         2    0.001    0.000    0.001    0.000 iostream.py:418(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:437(_schedule_flush)
#         2    0.001    0.000    0.003    0.001 iostream.py:500(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:96(_event_pipe)
#         2    0.000    0.000    0.000    0.000 linalg.py:102(get_linalg_error_extobj)
#         3    0.001    0.000    0.001    0.000 linalg.py:107(_makearray)
#         6    0.000    0.000    0.000    0.000 linalg.py:112(isComplexType)
#         3    0.000    0.000    0.000    0.000 linalg.py:125(_realType)
#         2    0.000    0.000    0.000    0.000 linalg.py:135(_commonType)
#         2    0.000    0.000    0.000    0.000 linalg.py:193(_assert_stacked_2d)
#         2    0.000    0.000    0.000    0.000 linalg.py:199(_assert_stacked_square)
#         1    0.000    0.000    0.000    0.000 linalg.py:2359(_norm_dispatcher)
#         1    0.000    0.000    0.000    0.000 linalg.py:2363(norm)
#         1    0.000    0.000    0.000    0.000 linalg.py:309(_solve_dispatcher)
#         1    0.001    0.001    0.002    0.002 linalg.py:313(solve)
#         1    0.000    0.000    0.000    0.000 linalg.py:472(_unary_dispatcher)
#         1    0.001    0.001    0.001    0.001 linalg.py:476(inv)
#        21    0.000    0.000    0.000    0.000 lines.py:1008(set_antialiased)
#        21    0.000    0.000    0.000    0.000 lines.py:1020(set_color)
#        21    0.000    0.000    0.000    0.000 lines.py:1032(set_drawstyle)
#        21    0.000    0.000    0.000    0.000 lines.py:1067(set_linewidth)
#        21    0.000    0.000    0.000    0.000 lines.py:1085(set_linestyle)
#        12    0.000    0.000    0.000    0.000 lines.py:1133(set_marker)
#        63    0.000    0.000    0.000    0.000 lines.py:1147(_set_markercolor)
#        21    0.000    0.000    0.000    0.000 lines.py:1161(set_markeredgecolor)
#        21    0.000    0.000    0.000    0.000 lines.py:1171(set_markerfacecolor)
#        21    0.000    0.000    0.000    0.000 lines.py:1181(set_markerfacecoloralt)
#        21    0.000    0.000    0.000    0.000 lines.py:1191(set_markeredgewidth)
#        21    0.000    0.000    0.000    0.000 lines.py:1206(set_markersize)
#        57    0.000    0.000    0.000    0.000 lines.py:1220(set_xdata)
#        39    0.000    0.000    0.000    0.000 lines.py:1232(set_ydata)
#        21    0.000    0.000    0.000    0.000 lines.py:1289(set_dash_joinstyle)
#        21    0.000    0.000    0.000    0.000 lines.py:1303(set_solid_joinstyle)
#        21    0.000    0.000    0.000    0.000 lines.py:1333(set_dash_capstyle)
#        21    0.000    0.000    0.000    0.000 lines.py:1347(set_solid_capstyle)
#        21    0.001    0.000    0.004    0.000 lines.py:276(__init__)
#        34    0.000    0.000    0.000    0.000 lines.py:31(_get_dash_pattern)
#        21    0.000    0.000    0.000    0.000 lines.py:492(set_pickradius)
#        21    0.000    0.000    0.000    0.000 lines.py:537(set_markevery)
#        74    0.000    0.000    0.000    0.000 lines.py:61(_scale_dashes)
#        39    0.000    0.000    0.000    0.000 lines.py:628(set_data)
#         6    0.000    0.000    0.001    0.000 lines.py:647(recache)
#        21    0.000    0.000    0.000    0.000 lines.py:711(set_transform)
#         6    0.000    0.000    0.001    0.000 lines.py:994(get_path)
#        34    0.000    0.000    0.001    0.000 markers.py:219(__init__)
#        68    0.000    0.000    0.000    0.000 markers.py:237(_recache)
#         1    0.000    0.000    0.000    0.000 markers.py:256(is_filled)
#        13    0.000    0.000    0.000    0.000 markers.py:259(get_fillstyle)
#        34    0.000    0.000    0.000    0.000 markers.py:266(_set_fillstyle)
#        34    0.000    0.000    0.001    0.000 markers.py:295(_set_marker)
#         1    0.000    0.000    0.000    0.000 markers.py:336(get_path)
#         1    0.000    0.000    0.000    0.000 markers.py:345(get_transform)
#        21    0.000    0.000    0.000    0.000 markers.py:371(_set_nothing)
#         1    0.000    0.000    0.000    0.000 markers.py:432(_half_fill)
#         1    0.000    0.000    0.000    0.000 markers.py:435(_set_circle)
#         6    0.000    0.000    0.000    0.000 markers.py:696(_set_tickup)
#         6    0.000    0.000    0.000    0.000 markers.py:702(_set_tickdown)
#         1    0.000    0.000    0.000    0.000 multiarray.py:1021(unravel_index)
#         3    0.000    0.000    0.000    0.000 multiarray.py:1071(copyto)
#         1    0.000    0.000    0.000    0.000 multiarray.py:1368(may_share_memory)
#        54    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 multiarray.py:341(where)
#         3    0.000    0.000    0.000    0.000 multiarray.py:613(min_scalar_type)
#        17    0.000    0.000    0.000    0.000 multiarray.py:736(dot)
#         2    0.000    0.000    0.000    0.000 multiarray.py:80(empty_like)
#         3    0.000    0.000    0.000    0.000 numeric.py:149(ones)
#        12    0.000    0.000    0.000    0.000 numerictypes.py:284(issubclass_)
#         6    0.000    0.000    0.000    0.000 numerictypes.py:358(issubdtype)
#         3    0.000    0.000    0.001    0.000 patches.py:1045(__init__)
#         3    0.000    0.000    0.001    0.000 patches.py:1095(set_xy)
#        16    0.000    0.000    0.003    0.000 patches.py:276(get_transform)
#        10    0.000    0.000    0.000    0.000 patches.py:318(set_antialiased)
#        32    0.000    0.000    0.000    0.000 patches.py:331(_set_edgecolor)
#        17    0.000    0.000    0.000    0.000 patches.py:346(set_edgecolor)
#        32    0.000    0.000    0.001    0.000 patches.py:357(_set_facecolor)
#        17    0.000    0.000    0.000    0.000 patches.py:364(set_facecolor)
#         6    0.000    0.000    0.000    0.000 patches.py:391(set_alpha)
#        15    0.000    0.000    0.000    0.000 patches.py:398(set_linewidth)
#         9    0.000    0.000    0.000    0.000 patches.py:418(set_linestyle)
#         9    0.000    0.000    0.000    0.000 patches.py:455(set_fill)
#        13    0.000    0.000    0.000    0.000 patches.py:477(set_capstyle)
#         9    0.000    0.000    0.000    0.000 patches.py:494(set_joinstyle)
#         9    0.000    0.000    0.000    0.000 patches.py:511(set_hatch)
#         9    0.000    0.000    0.003    0.000 patches.py:59(__init__)
#         2    0.000    0.000    0.002    0.001 patches.py:708(__init__)
#        18    0.000    0.000    0.000    0.000 patches.py:739(_convert_units)
#        16    0.000    0.000    0.003    0.000 patches.py:747(get_patch_transform)
#        16    0.000    0.000    0.001    0.000 patches.py:842(get_bbox)
#        17    0.000    0.000    0.000    0.000 path.py:191(_update_values)
#         7    0.000    0.000    0.000    0.000 path.py:200(vertices)
#         4    0.000    0.000    0.000    0.000 path.py:214(codes)
#         3    0.000    0.000    0.000    0.000 path.py:233(simplify_threshold)
#         3    0.000    0.000    0.000    0.000 path.py:245(should_simplify)
#         1    0.000    0.000    0.000    0.000 path.py:478(transformed)
#         1    0.000    0.000    0.000    0.000 path.py:793(unit_circle)
#        17    0.000    0.000    0.000    0.000 path.py:99(__init__)
#        12    0.000    0.000    0.001    0.000 pathlib.py:1079(__new__)
#        12    0.000    0.000    0.000    0.000 pathlib.py:1089(_init)
#        24    0.000    0.000    0.000    0.000 pathlib.py:303(splitroot)
#        12    0.000    0.000    0.001    0.000 pathlib.py:64(parse_parts)
#        12    0.000    0.000    0.001    0.000 pathlib.py:682(_parse_args)
#        12    0.000    0.000    0.001    0.000 pathlib.py:702(_from_parts)
#        12    0.000    0.000    0.000    0.000 pathlib.py:725(_format_parsed_parts)
#        12    0.000    0.000    0.000    0.000 pathlib.py:742(__str__)
#         1    0.000    0.000    0.000    0.000 pyplot.py:201(_get_required_interactive_framework)
#         1    0.000    0.000    0.000    0.000 pyplot.py:294(_warn_if_gui_out_of_main_thread)
#         1    0.000    0.000    0.009    0.009 pyplot.py:303(new_figure_manager)
#         1    0.000    0.000    0.001    0.001 pyplot.py:310(draw_if_interactive)
# ...
#        21    0.000    0.000    0.000    0.000 text.py:1265(set_usetex)
#        21    0.000    0.000    0.000    0.000 text.py:1283(set_parse_math)
#        51    0.000    0.000    0.002    0.000 text.py:162(update)
#        21    0.000    0.000    0.000    0.000 text.py:241(set_rotation_mode)
#         3    0.000    0.000    0.000    0.000 text.py:517(_update_clip_properties)
#         3    0.000    0.000    0.000    0.000 text.py:524(set_clip_box)
#        21    0.000    0.000    0.000    0.000 text.py:543(set_wrap)
#        24    0.000    0.000    0.000    0.000 text.py:936(set_color)
#        39    0.000    0.000    0.000    0.000 text.py:957(set_horizontalalignment)
#         3    0.000    0.000    0.000    0.000 threading.py:1059(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 threading.py:1126(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:529(is_set)
#        11    0.000    0.000    0.000    0.000 ticker.py:1640(nonsingular)
#        48    0.000    0.000    0.000    0.000 ticker.py:183(set_axis)
#        12    0.000    0.000    0.001    0.000 ticker.py:1945(__init__)
#        12    0.000    0.000    0.001    0.000 ticker.py:1986(_validate_steps)
#        12    0.000    0.000    0.000    0.000 ticker.py:2001(_staircase)
#        12    0.000    0.000    0.001    0.000 ticker.py:2007(set_params)
#         3    0.000    0.000    0.000    0.000 ticker.py:2133(view_limits)
#        21    0.000    0.000    0.000    0.000 ticker.py:265(_set_locator)
#        12    0.000    0.000    0.001    0.000 ticker.py:2740(__init__)
#        12    0.000    0.000    0.002    0.000 ticker.py:433(__init__)
#        12    0.000    0.000    0.000    0.000 ticker.py:480(set_useOffset)
#        12    0.000    0.000    0.000    0.000 ticker.py:559(set_useMathText)
#         9    0.000    0.000    0.000    0.000 transforms.py:1001(intervalx)
#         5    0.000    0.000    0.000    0.000 transforms.py:1006(intervaly)
#         3    0.000    0.000    0.000    0.000 transforms.py:1019(minpos)
#         8    0.000    0.000    0.000    0.000 transforms.py:1030(minposx)
#        68    0.000    0.000    0.000    0.000 transforms.py:1052(get_points)
#       246    0.000    0.000    0.000    0.000 transforms.py:107(__init__)
#         2    0.000    0.000    0.000    0.000 transforms.py:1070(set)
#        19    0.000    0.000    0.001    0.000 transforms.py:1100(__init__)
#         1    0.000    0.000    0.000    0.000 transforms.py:1122(get_points)
#        51    0.000    0.000    0.001    0.000 transforms.py:1348(__add__)
#         4    0.000    0.000    0.000    0.000 transforms.py:1363(_iter_break_from_left_to_right)
#        10    0.000    0.000    0.000    0.000 transforms.py:1375(depth)
#         2    0.000    0.000    0.000    0.000 transforms.py:1389(contains_branch)
#         1    0.000    0.000    0.000    0.000 transforms.py:1408(contains_branch_seperately)
#         1    0.000    0.000    0.000    0.000 transforms.py:1426(__sub__)
#        82    0.000    0.000    0.000    0.000 transforms.py:170(invalidate)
#         2    0.000    0.000    0.000    0.000 transforms.py:1710(__init__)
#         2    0.000    0.000    0.000    0.000 transforms.py:1719(_init)
#         2    0.000    0.000    0.000    0.000 transforms.py:1726(__eq__)
#         3    0.000    0.000    0.000    0.000 transforms.py:1735(_set)
#         1    0.000    0.000    0.000    0.000 transforms.py:1752(set)
#         3    0.000    0.000    0.000    0.000 transforms.py:1772(<lambda>)
#       122    0.000    0.000    0.000    0.000 transforms.py:1783(__init__)
#         5    0.000    0.000    0.000    0.000 transforms.py:1791(__eq__)
#         3    0.000    0.000    0.000    0.000 transforms.py:1796(transform)
#    157/82    0.000    0.000    0.000    0.000 transforms.py:180(_invalidate_internal)
#         1    0.000    0.000    0.000    0.000 transforms.py:1846(frozen)
#         8    0.000    0.000    0.000    0.000 transforms.py:1850(is_separable)
#         3    0.000    0.000    0.000    0.000 transforms.py:1862(transform_affine)
#         1    0.000    0.000    0.001    0.001 transforms.py:1883(inverted)
#        32    0.000    0.000    0.002    0.000 transforms.py:1900(__init__)
#         3    0.000    0.000    0.000    0.000 transforms.py:1940(get_matrix)
#        16    0.000    0.000    0.001    0.000 transforms.py:1996(rotate)
#        16    0.001    0.000    0.001    0.000 transforms.py:2012(rotate_deg)
#        16    0.000    0.000    0.002    0.000 transforms.py:2032(rotate_deg_around)
#        32    0.000    0.000    0.000    0.000 transforms.py:2044(translate)
#        14    0.001    0.000    0.001    0.000 transforms.py:2057(scale)
#       114    0.001    0.000    0.001    0.000 transforms.py:207(set_children)
#        17    0.000    0.000    0.000    0.000 transforms.py:2126(get_matrix)
#         1    0.000    0.000    0.000    0.000 transforms.py:2130(transform)
#         2    0.000    0.000    0.000    0.000 transforms.py:2166(__eq__)
#         2    0.000    0.000    0.000    0.000 transforms.py:2194(__init__)
#        17    0.000    0.000    0.000    0.000 transforms.py:222(<lambda>)
#         7    0.000    0.000    0.000    0.000 transforms.py:2285(__init__)
#         3    0.000    0.000    0.000    0.000 transforms.py:2311(get_matrix)
#         9    0.000    0.000    0.000    0.000 transforms.py:2327(blended_transform_factory)
#        51    0.000    0.000    0.000    0.000 transforms.py:2351(__init__)
#     47/33    0.000    0.000    0.000    0.000 transforms.py:2380(_invalidate_internal)
#       4/2    0.000    0.000    0.000    0.000 transforms.py:2395(__eq__)
#         4    0.000    0.000    0.000    0.000 transforms.py:2402(_iter_break_from_left_to_right)
#       6/3    0.000    0.000    0.000    0.000 transforms.py:2408(<lambda>)
#         3    0.000    0.000    0.000    0.000 transforms.py:2409(<lambda>)
#        51    0.000    0.000    0.001    0.000 transforms.py:2508(composite_transform_factory)
#        18    0.000    0.000    0.000    0.000 transforms.py:2586(__init__)
#         1    0.000    0.000    0.000    0.000 transforms.py:259(frozen)
#         1    0.000    0.000    0.000    0.000 transforms.py:2644(__init__)
#         1    0.000    0.000    0.000    0.000 transforms.py:2656(get_matrix)
#        16    0.000    0.000    0.000    0.000 transforms.py:266(x0)
#        13    0.000    0.000    0.000    0.000 transforms.py:2678(__init__)
#        16    0.000    0.000    0.000    0.000 transforms.py:276(y0)
#        14    0.000    0.000    0.000    0.000 transforms.py:2839(nonsingular)
#        18    0.000    0.000    0.000    0.000 transforms.py:356(intervalx)
#         9    0.000    0.000    0.000    0.000 transforms.py:365(intervaly)
#         1    0.000    0.000    0.000    0.000 transforms.py:374(width)
#         1    0.000    0.000    0.000    0.000 transforms.py:380(height)
#         1    0.000    0.000    0.000    0.000 transforms.py:392(bounds)
#        43    0.000    0.000    0.001    0.000 transforms.py:767(__init__)
#         1    0.000    0.000    0.000    0.000 transforms.py:797(frozen)
#        21    0.000    0.000    0.000    0.000 transforms.py:803(unit)
#         2    0.000    0.000    0.000    0.000 transforms.py:808(null)
#         2    0.000    0.000    0.000    0.000 transforms.py:813(from_bounds)
#        19    0.000    0.000    0.001    0.000 transforms.py:822(from_extents)
#         3    0.000    0.000    0.000    0.000 transforms.py:869(update_from_path)
#         1    0.000    0.000    0.000    0.000 transforms.py:905(update_from_data_x)
#         3    0.000    0.000    0.000    0.000 transforms.py:945(update_from_data_xy)
#     20/10    0.000    0.000    0.000    0.000 units.py:181(get_converter)
#        18    0.000    0.000    0.000    0.000 units.py:56(_is_natively_supported)
#        16    0.000    0.000    0.000    0.000 weakref.py:47(__new__)
#         2    0.000    0.000    0.000    0.000 widgets.py:36(__init__)
#        86    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x104ca88c0}
#       151    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        13    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#        40    0.004    0.000    0.004    0.000 {built-in method _warnings.warn}
#        28    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#     10172    0.002    0.000    0.002    0.000 {built-in method builtins.callable}
#       119    0.000    0.000    0.000    0.000 {built-in method builtins.delattr}
#         1    0.000    0.000   31.576   31.576 {built-in method builtins.exec}
#      1200    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       100    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#    102/78    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#       386    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#      7099    0.002    0.000    0.002    0.000 {built-in method builtins.isinstance}
#        83    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       133    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#       335    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#      9978    0.007    0.000    0.007    0.000 {built-in method builtins.max}
#      4980    0.002    0.000    0.002    0.000 {built-in method builtins.min}
#       268    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#         1    0.001    0.001    0.003    0.003 {built-in method builtins.print}
#       194    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        46    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#        16    0.000    0.000    0.000    0.000 {built-in method math.cos}
#        16    0.000    0.000    0.000    0.000 {built-in method math.radians}
#        16    0.000    0.000    0.000    0.000 {built-in method math.sin}
#         3    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.affine_transform}
#         3    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.update_path_extents}
#       158    0.001    0.000    0.001    0.000 {built-in method numpy.array}
#       119    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#       188    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#   274/195    0.001    0.000    0.008    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        14    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        16    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#        24    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#   4972/16    1.271    0.000   31.509    1.969 {built-in method scipy.integrate._quadpack._qagse}
#       168    0.000    0.000    0.000    0.000 {built-in method sys.intern}
#      1650    0.000    0.000    0.000    0.000 {function RcParams.__getitem__ at 0x11ad2a550}
#         2    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         7    0.000    0.000    0.001    0.000 {method 'all' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       611    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         9    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.generic' objects}
#       114    0.002    0.000    0.002    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        44    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#        13    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       691    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'indices' of 'slice' objects}
#         2    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.generic' objects}
#      1495    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        33    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#       154    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         4    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#      5270    0.002    0.000    0.002    0.000 {method 'pop' of 'dict' objects}
#        53    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        46    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        34    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        36    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        24    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       176    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#       123    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#     23/22    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.generic' objects}
#     44/43    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}

# %%
cProfile.run('finiteElement.getIntegral(Point(6, 5))')
# Out:
#          156186 function calls (156102 primitive calls) in 0.191 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     10815    0.017    0.000    0.137    0.000 318662846.py:120(evaluate)
#     10804    0.016    0.000    0.016    0.000 318662846.py:14(area)
#     10815    0.012    0.000    0.184    0.000 318662846.py:155(integrand)
#         1    0.000    0.000    0.191    0.191 318662846.py:158(getIntegral)
#        21    0.000    0.000    0.000    0.000 318662846.py:164(<lambda>)
#     10804    0.019    0.000    0.019    0.000 318662846.py:19(area_pt)
#     10805    0.003    0.000    0.003    0.000 318662846.py:2(__init__)
#     45504    0.058    0.000    0.058    0.000 318662846.py:27(is_in)
#     45504    0.024    0.000    0.119    0.000 318662846.py:34(evaluate)
#     10815    0.035    0.000    0.035    0.000 440238750.py:17(electronDensity)
#         1    0.000    0.000    0.191    0.191 <string>:1(<module>)
#      22/1    0.000    0.000    0.191    0.191 quadpack.py:445(_quad)
#      22/1    0.000    0.000    0.191    0.191 quadpack.py:49(quad)
#         1    0.000    0.000    0.191    0.191 quadpack.py:530(dblquad)
#        21    0.000    0.000    0.000    0.000 quadpack.py:597(temp_ranges)
#         1    0.000    0.000    0.191    0.191 quadpack.py:694(nquad)
#         1    0.000    0.000    0.000    0.000 quadpack.py:815(<listcomp>)
#         1    0.000    0.000    0.000    0.000 quadpack.py:829(__init__)
#         1    0.000    0.000    0.000    0.000 quadpack.py:832(__call__)
#         1    0.000    0.000    0.000    0.000 quadpack.py:842(__init__)
#        22    0.000    0.000    0.000    0.000 quadpack.py:845(__call__)
#         1    0.000    0.000    0.000    0.000 quadpack.py:851(__init__)
#      22/1    0.000    0.000    0.191    0.191 quadpack.py:861(integrate)
#        44    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.191    0.191 {built-in method builtins.exec}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        44    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#      22/1    0.007    0.000    0.191    0.191 {built-in method scipy.integrate._quadpack._qagse}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        22    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}

# %%
finiteElement.getIntegral(Point(6, 5))
# Out:
# 0.00010224424095003971

# %%
Test.plot(-2, 2, -2, 2, 50, electronDensity)

# %%
rgb
# Out:
# array([[[0.68481796, 0.        , 0.16496235, 1.        ],
#         [0.75905341, 0.05379805, 0.18212881, 1.        ],
#         [0.84628762, 0.14192815, 0.20761217, 1.        ],
#         [0.92329873, 0.27363132, 0.23586449, 1.        ],
#         [0.95482765, 0.39779499, 0.29295771, 1.        ],
#         [0.95482765, 0.39779499, 0.29295771, 1.        ],
#         [0.92329873, 0.27363132, 0.23586449, 1.        ],
#         [0.84628762, 0.14192815, 0.20761217, 1.        ],
#         [0.75905341, 0.05379805, 0.18212881, 1.        ],
#         [0.68481796, 0.        , 0.16496235, 1.        ]],
#
#        [[0.73246635, 0.04995992, 0.16913513, 1.        ],
#         [0.84716872, 0.17687766, 0.19161746, 1.        ],
#         [0.94752375, 0.45880295, 0.30754923, 1.        ],
#         [0.98984129, 0.84021039, 0.50778829, 1.        ],
#         [0.9978578 , 0.93506363, 0.66781057, 1.        ],
#         [0.9978578 , 0.93506363, 0.66781057, 1.        ],
#         [0.98984129, 0.84021039, 0.50778829, 1.        ],
#         [0.94752375, 0.45880295, 0.30754923, 1.        ],
#         [0.84716872, 0.17687766, 0.19161746, 1.        ],
#         [0.73246635, 0.04995992, 0.16913513, 1.        ]],
#
#        [[0.79237962, 0.11921582, 0.17438862, 1.        ],
#         [0.93409703, 0.41506196, 0.27822835, 1.        ],
#         [0.99502678, 0.84924724, 0.57542699, 1.        ],
#         [0.99960528, 0.98776362, 0.93702146, 1.        ],
#         [1.        , 1.        , 1.        , 1.        ],
#         [1.        , 1.        , 1.        , 1.        ],
#         [0.99960528, 0.98776362, 0.93702146, 1.        ],
#         [0.99502678, 0.84924724, 0.57542699, 1.        ],
#         [0.93409703, 0.41506196, 0.27822835, 1.        ],
#         [0.79237962, 0.11921582, 0.17438862, 1.        ]],
#
#        [[0.85396026, 0.20068345, 0.17298495, 1.        ],
#         [0.97773316, 0.64975761, 0.38770836, 1.        ],
#         [0.99884529, 0.96420392, 0.81576368, 1.        ],
#         [0.92529849, 0.96696617, 0.98085539, 1.        ],
#         [0.78369256, 0.95312728, 0.97394422, 1.        ],
#         [0.78369256, 0.95312728, 0.97394422, 1.        ],
#         [0.92529849, 0.96696617, 0.98085539, 1.        ],
#         [0.99884529, 0.96420392, 0.81576368, 1.        ],
#         [0.97773316, 0.64975761, 0.38770836, 1.        ],
#         [0.85396026, 0.20068345, 0.17298495, 1.        ]],
#
#        [[0.87541165, 0.25386791, 0.18696204, 1.        ],
#         [0.98997067, 0.6959818 , 0.41043275, 1.        ],
#         [0.95572377, 0.98286082, 0.87872164, 1.        ],
#         [0.53978525, 0.74074967, 0.855887  , 1.        ],
#         [0.26158331, 0.28827549, 0.73450156, 1.        ],
#         [0.26158331, 0.28827549, 0.73450156, 1.        ],
#         [0.53978525, 0.74074967, 0.855887  , 1.        ],
#         [0.95572377, 0.98286082, 0.87872164, 1.        ],
#         [0.98997067, 0.6959818 , 0.41043275, 1.        ],
#         [0.87541165, 0.25386791, 0.18696204, 1.        ]],
#
#        [[0.86263396, 0.23071067, 0.16990779, 1.        ],
#         [0.98756563, 0.62307792, 0.33194983, 1.        ],
#         [0.93462609, 0.97469397, 0.82093234, 1.        ],
#         [0.30056023, 0.53244908, 0.74009611, 1.        ],
#         [0.12782741, 0.14087102, 0.44515205, 1.        ],
#         [0.12782741, 0.14087102, 0.44515205, 1.        ],
#         [0.30056023, 0.53244908, 0.74009611, 1.        ],
#         [0.93462609, 0.97469397, 0.82093234, 1.        ],
#         [0.98756563, 0.62307792, 0.33194983, 1.        ],
#         [0.86263396, 0.23071067, 0.16990779, 1.        ]],
#
#        [[0.81340127, 0.15801317, 0.13620406, 1.        ],
#         [0.96144952, 0.39362711, 0.22621881, 1.        ],
#         [0.99670479, 0.89784844, 0.47424329, 1.        ],
#         [0.55462937, 0.80305218, 0.88585979, 1.        ],
#         [0.05665292, 0.32007147, 0.62203888, 1.        ],
#         [0.05665292, 0.32007147, 0.62203888, 1.        ],
#         [0.55462937, 0.80305218, 0.88585979, 1.        ],
#         [0.99670479, 0.89784844, 0.47424329, 1.        ],
#         [0.96144952, 0.39362711, 0.22621881, 1.        ],
#         [0.81340127, 0.15801317, 0.13620406, 1.        ]],
#
#        [[0.7243197 , 0.09054104, 0.13244322, 1.        ],
#         [0.87499876, 0.22253419, 0.14917127, 1.        ],
#         [0.98252708, 0.47034471, 0.16752855, 1.        ],
#         [0.9959448 , 0.87428874, 0.35298552, 1.        ],
#         [0.89034987, 0.95755479, 0.69965398, 1.        ],
#         [0.89034987, 0.95755479, 0.69965398, 1.        ],
#         [0.9959448 , 0.87428874, 0.35298552, 1.        ],
#         [0.98252708, 0.47034471, 0.16752855, 1.        ],
#         [0.87499876, 0.22253419, 0.14917127, 1.        ],
#         [0.7243197 , 0.09054104, 0.13244322, 1.        ]],
#
#        [[0.66401236, 0.04007784, 0.13568017, 1.        ],
#         [0.74546875, 0.10791828, 0.11691147, 1.        ],
#         [0.86157204, 0.1787932 , 0.11985039, 1.        ],
#         [0.94934139, 0.20317433, 0.10613888, 1.        ],
#         [0.97967851, 0.38399609, 0.07457201, 1.        ],
#         [0.97967851, 0.38399609, 0.07457201, 1.        ],
#         [0.94934139, 0.20317433, 0.10613888, 1.        ],
#         [0.86157204, 0.1787932 , 0.11985039, 1.        ],
#         [0.74546875, 0.10791828, 0.11691147, 1.        ],
#         [0.66401236, 0.04007784, 0.13568017, 1.        ]],
#
#        [[0.62132444, 0.        , 0.13815398, 1.        ],
#         [0.6374253 , 0.0362397 , 0.1226865 , 1.        ],
#         [0.6704117 , 0.06782871, 0.09921967, 1.        ],
#         [0.7440628 , 0.0850653 , 0.07332452, 1.        ],
#         [0.78321796, 0.08678359, 0.06391212, 1.        ],
#         [0.78321796, 0.08678359, 0.06391212, 1.        ],
#         [0.7440628 , 0.0850653 , 0.07332452, 1.        ],
#         [0.6704117 , 0.06782871, 0.09921967, 1.        ],
#         [0.6374253 , 0.0362397 , 0.1226865 , 1.        ],
#         [0.62132444, 0.        , 0.13815398, 1.        ]]])

# %%
rgb.shape
# Out:
# (10, 10, 4)

# %%
new_img = rgb.transpose((2, 0, 1))
# Dimensions: [3, m, n]
new_img = rgb.reshape(rgb.shape[0]*rgb.shape[1], rgb.shape[2])

# %%
new_img
# Out:
# array([[0.68481796, 0.        , 0.16496235, 1.        ],
#        [0.75905341, 0.05379805, 0.18212881, 1.        ],
#        [0.84628762, 0.14192815, 0.20761217, 1.        ],
#        [0.92329873, 0.27363132, 0.23586449, 1.        ],
#        [0.95482765, 0.39779499, 0.29295771, 1.        ],
#        [0.95482765, 0.39779499, 0.29295771, 1.        ],
#        [0.92329873, 0.27363132, 0.23586449, 1.        ],
#        [0.84628762, 0.14192815, 0.20761217, 1.        ],
#        [0.75905341, 0.05379805, 0.18212881, 1.        ],
#        [0.68481796, 0.        , 0.16496235, 1.        ],
#        [0.73246635, 0.04995992, 0.16913513, 1.        ],
#        [0.84716872, 0.17687766, 0.19161746, 1.        ],
#        [0.94752375, 0.45880295, 0.30754923, 1.        ],
#        [0.98984129, 0.84021039, 0.50778829, 1.        ],
#        [0.9978578 , 0.93506363, 0.66781057, 1.        ],
#        [0.9978578 , 0.93506363, 0.66781057, 1.        ],
#        [0.98984129, 0.84021039, 0.50778829, 1.        ],
#        [0.94752375, 0.45880295, 0.30754923, 1.        ],
#        [0.84716872, 0.17687766, 0.19161746, 1.        ],
#        [0.73246635, 0.04995992, 0.16913513, 1.        ],
#        [0.79237962, 0.11921582, 0.17438862, 1.        ],
#        [0.93409703, 0.41506196, 0.27822835, 1.        ],
#        [0.99502678, 0.84924724, 0.57542699, 1.        ],
#        [0.99960528, 0.98776362, 0.93702146, 1.        ],
#        [1.        , 1.        , 1.        , 1.        ],
#        [1.        , 1.        , 1.        , 1.        ],
#        [0.99960528, 0.98776362, 0.93702146, 1.        ],
#        [0.99502678, 0.84924724, 0.57542699, 1.        ],
#        [0.93409703, 0.41506196, 0.27822835, 1.        ],
#        [0.79237962, 0.11921582, 0.17438862, 1.        ],
#        [0.85396026, 0.20068345, 0.17298495, 1.        ],
#        [0.97773316, 0.64975761, 0.38770836, 1.        ],
#        [0.99884529, 0.96420392, 0.81576368, 1.        ],
#        [0.92529849, 0.96696617, 0.98085539, 1.        ],
#        [0.78369256, 0.95312728, 0.97394422, 1.        ],
#        [0.78369256, 0.95312728, 0.97394422, 1.        ],
#        [0.92529849, 0.96696617, 0.98085539, 1.        ],
#        [0.99884529, 0.96420392, 0.81576368, 1.        ],
#        [0.97773316, 0.64975761, 0.38770836, 1.        ],
#        [0.85396026, 0.20068345, 0.17298495, 1.        ],
#        [0.87541165, 0.25386791, 0.18696204, 1.        ],
#        [0.98997067, 0.6959818 , 0.41043275, 1.        ],
#        [0.95572377, 0.98286082, 0.87872164, 1.        ],
#        [0.53978525, 0.74074967, 0.855887  , 1.        ],
#        [0.26158331, 0.28827549, 0.73450156, 1.        ],
#        [0.26158331, 0.28827549, 0.73450156, 1.        ],
#        [0.53978525, 0.74074967, 0.855887  , 1.        ],
#        [0.95572377, 0.98286082, 0.87872164, 1.        ],
#        [0.98997067, 0.6959818 , 0.41043275, 1.        ],
#        [0.87541165, 0.25386791, 0.18696204, 1.        ],
#        [0.86263396, 0.23071067, 0.16990779, 1.        ],
#        [0.98756563, 0.62307792, 0.33194983, 1.        ],
#        [0.93462609, 0.97469397, 0.82093234, 1.        ],
#        [0.30056023, 0.53244908, 0.74009611, 1.        ],
#        [0.12782741, 0.14087102, 0.44515205, 1.        ],
#        [0.12782741, 0.14087102, 0.44515205, 1.        ],
#        [0.30056023, 0.53244908, 0.74009611, 1.        ],
#        [0.93462609, 0.97469397, 0.82093234, 1.        ],
#        [0.98756563, 0.62307792, 0.33194983, 1.        ],
#        [0.86263396, 0.23071067, 0.16990779, 1.        ],
#        [0.81340127, 0.15801317, 0.13620406, 1.        ],
#        [0.96144952, 0.39362711, 0.22621881, 1.        ],
#        [0.99670479, 0.89784844, 0.47424329, 1.        ],
#        [0.55462937, 0.80305218, 0.88585979, 1.        ],
#        [0.05665292, 0.32007147, 0.62203888, 1.        ],
#        [0.05665292, 0.32007147, 0.62203888, 1.        ],
#        [0.55462937, 0.80305218, 0.88585979, 1.        ],
#        [0.99670479, 0.89784844, 0.47424329, 1.        ],
#        [0.96144952, 0.39362711, 0.22621881, 1.        ],
#        [0.81340127, 0.15801317, 0.13620406, 1.        ],
#        [0.7243197 , 0.09054104, 0.13244322, 1.        ],
#        [0.87499876, 0.22253419, 0.14917127, 1.        ],
#        [0.98252708, 0.47034471, 0.16752855, 1.        ],
#        [0.9959448 , 0.87428874, 0.35298552, 1.        ],
#        [0.89034987, 0.95755479, 0.69965398, 1.        ],
#        [0.89034987, 0.95755479, 0.69965398, 1.        ],
#        [0.9959448 , 0.87428874, 0.35298552, 1.        ],
#        [0.98252708, 0.47034471, 0.16752855, 1.        ],
#        [0.87499876, 0.22253419, 0.14917127, 1.        ],
#        [0.7243197 , 0.09054104, 0.13244322, 1.        ],
#        [0.66401236, 0.04007784, 0.13568017, 1.        ],
#        [0.74546875, 0.10791828, 0.11691147, 1.        ],
#        [0.86157204, 0.1787932 , 0.11985039, 1.        ],
#        [0.94934139, 0.20317433, 0.10613888, 1.        ],
#        [0.97967851, 0.38399609, 0.07457201, 1.        ],
#        [0.97967851, 0.38399609, 0.07457201, 1.        ],
#        [0.94934139, 0.20317433, 0.10613888, 1.        ],
#        [0.86157204, 0.1787932 , 0.11985039, 1.        ],
#        [0.74546875, 0.10791828, 0.11691147, 1.        ],
#        [0.66401236, 0.04007784, 0.13568017, 1.        ],
#        [0.62132444, 0.        , 0.13815398, 1.        ],
#        [0.6374253 , 0.0362397 , 0.1226865 , 1.        ],
#        [0.6704117 , 0.06782871, 0.09921967, 1.        ],
#        [0.7440628 , 0.0850653 , 0.07332452, 1.        ],
#        [0.78321796, 0.08678359, 0.06391212, 1.        ],
#        [0.78321796, 0.08678359, 0.06391212, 1.        ],
#        [0.7440628 , 0.0850653 , 0.07332452, 1.        ],
#        [0.6704117 , 0.06782871, 0.09921967, 1.        ],
#        [0.6374253 , 0.0362397 , 0.1226865 , 1.        ],
#        [0.62132444, 0.        , 0.13815398, 1.        ]])

# %%
fin=FiniteElement(0, 0, 1, 1, 1)

# %%
Test.plot(0, 2, -2, 0,100,fin.evaluate)

# %%
fin.evaluate(1,-1)
# Out:
# 1

# %%
fin.evaluate(1,-1)
# Out:
# 4.0

# %%
integrate.dblquad(fin.evaluate, -2, 0,lambda x: 0, lambda x: 2)[0]
# Out:
# 0.6666666498972109

# %%
fin.evaluate(1.8,-1.8)
# Out:
# 0

# %%
integrate.dblquad(electronDensity, -2, 0,lambda x: 0, lambda x: 2,epsabs=1e-8)[0]
# Out:
# 0.090866060540632

# %%
Test.plot(0, 0.4, -0.4, 0,100,finiteElement.finiteElements[5, 5].evaluate)
Test.plot(0, 0.4, -0.4, 0,100,electronDensity)

# %%
def lol(x, y):
    return electronDensity(x, y)*fin.evaluate(x, y)

# %%
test=[(integrate.dblquad(lol, -2, 0,lambda x: 0, lambda x: 2,epsabs=1e-8*10**i)[0]) for i in range(0, 7)]

# %%
test
# Out:
# [0.0016191353028300304,
#  0.0016191286222514505,
#  0.0016191289772780834,
#  0.00161919315870105,
#  0.0016219522329523855,
#  0.001613626045322107,
#  0.0015999807360674192]

# %%
1e-8*10**4
# Out:
# 0.0001

# %%
cProfile.run('integrate.dblquad(lol, -2, 0,lambda x: 0, lambda x: 2)[0]')
# Out:
#          473690 function calls (473438 primitive calls) in 0.569 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     38073    0.113    0.000    0.113    0.000 1226877424.py:16(electronDensity)
#     38073    0.027    0.000    0.546    0.000 2234026894.py:1(lol)
#     17993    0.071    0.000    0.071    0.000 74039619.py:14(area)
#     17993    0.031    0.000    0.031    0.000 74039619.py:18(area_pt)
#     17993    0.005    0.000    0.005    0.000 74039619.py:2(__init__)
#    152292    0.192    0.000    0.192    0.000 74039619.py:23(is_in)
#    152292    0.061    0.000    0.361    0.000 74039619.py:35(evaluate)
#     38073    0.045    0.000    0.406    0.000 74039619.py:84(evaluate)
#        63    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    0.569    0.569 <string>:1(<module>)
#      64/1    0.000    0.000    0.568    0.568 quadpack.py:445(_quad)
#      64/1    0.000    0.000    0.568    0.568 quadpack.py:49(quad)
#         1    0.000    0.000    0.569    0.569 quadpack.py:530(dblquad)
#        63    0.000    0.000    0.000    0.000 quadpack.py:597(temp_ranges)
#         1    0.000    0.000    0.569    0.569 quadpack.py:694(nquad)
#         1    0.000    0.000    0.000    0.000 quadpack.py:815(<listcomp>)
#         1    0.000    0.000    0.000    0.000 quadpack.py:829(__init__)
#         1    0.000    0.000    0.000    0.000 quadpack.py:832(__call__)
#         1    0.000    0.000    0.000    0.000 quadpack.py:842(__init__)
#        64    0.000    0.000    0.000    0.000 quadpack.py:845(__call__)
#         1    0.000    0.000    0.000    0.000 quadpack.py:851(__init__)
#      64/1    0.001    0.000    0.569    0.569 quadpack.py:861(integrate)
#         1    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#       128    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.569    0.569 {built-in method builtins.exec}
#        65    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       128    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        64    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#      64/1    0.021    0.000    0.568    0.568 {built-in method scipy.integrate._quadpack._qagse}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        64    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}

# %%
integrate.dblquad(lol, -2, 0,lambda x: 0, lambda x: 2,epsabs=1e-4)[0]
# Out:
# 0.0016219522329523855

# %%
def integrand(x, y):
    return (1/finiteElement.eps)*finiteElement.electronDensity(x,y)*finiteElement.finiteElements[5, 5].evaluate(x, y)

# %%
integrate.dblquad(integrand, -2, 0,lambda x: 0, lambda x: 2,epsabs=1e-5)[0]
# Out:
# 0.00161919315870105

# %%
0.0016191281781632982
